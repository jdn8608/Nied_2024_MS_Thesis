# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib notebook 
import numpy as np
import scipy as sp

import h5py as h5
import pandas as pd

from tensorflow import keras
import tensorflow as tf
import pickle
from tqdm.notebook import tqdm

import matplotlib
import glob
import os
import random
import time
# Out:
# 2024-06-19 11:23:26.008911: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import ydf

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Activation, SeparableConv2D, BatchNormalization, UpSampling2D
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, DepthwiseConv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K # Losses

# %%
from numba import jit, cuda
from timeit import default_timer as timer

# %%
import functools
import imageio

# %%
# %matplotlib notebook

# %%
print(tf.__version__)
print('1: ', tf.config.list_physical_devices('GPU'))
print('2: ', tf.test.is_built_with_cuda())
print('3: ', tf.test.gpu_device_name())
print('4: ', tf.config.get_visible_devices())
print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Available GPUs: ", tf.config.list_physical_devices('GPU'))
# Out:
# 2.4.1
# 1:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2:  True
# 3:  /device:GPU:0
# 4:  [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num CPUs Available:  1
# Num GPUs Available:  1
# Available GPUs:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-06-19 11:23:30.564693: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-06-19 11:23:30.564856: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2024-06-19 11:23:30.581585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:82:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2024-06-19 11:23:30.581668: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-06-19 11:23:30.586639: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-06-19 11:23:30.586719: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-06-19 11:23:30.591132: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-06-19 11:23:30.592345: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-06-19 11:23:30.597055: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-06-19 11:23:30.599728: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-06-19 11:23:30.608605: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-06-19 11:23:30.609866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-06-19 11:23:30.610612: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-19 11:23:30.613335: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-06-19 11:23:30.614283: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:82:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2024-06-19 11:23:30.614365: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-06-19 11:23:30.614424: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-06-19 11:23:30.614476: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-06-19 11:23:30.614527: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-06-19 11:23:30.614577: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-06-19 11:23:30.614644: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-06-19 11:23:30.614700: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-06-19 11:23:30.614751: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-06-19 11:23:30.616272: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-06-19 11:23:30.616380: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-06-19 11:23:31.340083: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-06-19 11:23:31.340140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-06-19 11:23:31.340158: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-06-19 11:23:31.341494: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/device:GPU:0 with 902 MB memory) -> physical GPU (device: 0, name: TITAN RTX, pci bus id: 0000:82:00.0, compute capability: 7.5)

# %%
import xarray as xr

# %% [markdown]
# # Evaluate Labels

# %%
files = glob.glob('/data/keeling/a/jdnied2/a/MODIS_ML/data/output/*')

# %%
labels_dir = '/data/keeling/a/jdnied2/c/ML/MOD-CM-NN/data/labels/labels_v03.csv'
temp = pd.read_csv(f'{labels_dir}', sep=',',index_col=False)
uniqued_frame = temp.drop_duplicates(subset='Filename', keep='last')
np_uniq = np.array(uniqued_frame)
print(len(uniqued_frame))
indices = np.where(uniqued_frame['Label']>=3)
print(len(indices[0]))
indices_good = np.where(uniqued_frame['Label']>=3)
indices_bad = np.where(uniqued_frame['Label']<3)



training_labels = np_uniq[indices]
# training_labels = np_uniq
print(len(training_labels))
# Out:
# 634
# 500
# 500

# %%
uniqued_frame['Filename']
# Out:
# 0      /data/keeling/a/jdnied2/a/MODIS_ML/data/output...
# 1      /data/keeling/a/jdnied2/a/MODIS_ML/data/output...
# 2      /data/keeling/a/jdnied2/a/MODIS_ML/data/output...
# 4      /data/keeling/a/jdnied2/a/MODIS_ML/data/output...
# 5      /data/keeling/a/jdnied2/a/MODIS_ML/data/output...
#                              ...
# 692    /data/keeling/a/jdnied2/a/MODIS_ML/data/output...
# 693    /data/keeling/a/jdnied2/a/MODIS_ML/data/output...
# 694    /data/keeling/a/jdnied2/a/MODIS_ML/data/output...
# 695    /data/keeling/a/jdnied2/a/MODIS_ML/data/output...
# 696    /data/keeling/a/jdnied2/a/MODIS_ML/data/output...
# Name: Filename, Length: 634, dtype: object

# %%
use_files = []
for tr in training_labels:
    use_files.append(tr[0])
len(use_files)
# Out:
# 500

# %% [markdown]
# # LOAD Data

# %%
def format_bands_to_use(bands_array):
    return [f'Band_{b}.0' for b in bands_array]

# %%
def get_modis_data(bands_to_use, files):
    bands = format_bands_to_use(bands_to_use)
#     bands.append('Longitude')
#     bands.append('Latitude')
    print(bands)
    
    rad_images = np.zeros((len(files),len(bands),64,64),dtype=np.float32)
    mask_images = np.zeros((len(files),64,64),dtype=np.float32)
    data_index = 0

    for line in tqdm(files):
        l_split = line.split('+')
        file = l_split[0]
        key = l_split[1]

        f1 = h5.File(file,'r')
        group = f1[key]

        labels = np.array(list(group['FeatureLabels'])).astype('U13')
        bdan_indis = []
        for b in bands:
            bdan_indis.append(np.where(labels==b)[0][0])

        rad_images[data_index] = np.array(group['ImageFeatures'])[bdan_indis]

        mask_images[data_index] = np.array(group['ImageClassification'])

        data_index+=1
        f1.close()
    print(np.shape(rad_images))
    rad_images_reshaped = np.swapaxes(np.swapaxes(rad_images,2,1),2,3)
    print(np.shape(rad_images_reshaped))
    
    return rad_images_reshaped, mask_images

# %%
def norm_mm(x):
    return ((x-np.min(x))/(np.max(x)-np.min(x)), np.min(x), np.max(x))
def norm(x,tr_min,tr_max):
    return (x-tr_min)/(tr_max-tr_min)
def make_binary(mask):
    bin_mask = np.copy(mask)
    bin_mask[bin_mask==1] = 0
    bin_mask[bin_mask==2] = 1
    bin_mask[bin_mask==3] = 1
    return bin_mask

# %%
mod_rad, mod_cm = get_modis_data([1,2,20,26,27,29,31,32,35], np.array(use_files))
misr_cm = np.zeros(np.shape(mod_cm))
'/data/keeling/a/jdnied2/c/ML/MOD-CM-NN/data/MISR_TRAIN_TEST_DATA'
for i, f in enumerate(np.array(use_files)):
    date = f.split('_')[-3]
    im_n = f.split('+')[-1]
    misr_cm[i] = np.load(glob.glob(
        f'/data/keeling/a/jdnied2/c/ML/MOD-CM-NN/data/MISR_TRAIN_TEST_DATA/{im_n}*{date}*.npy')[0])
misr_cm = make_binary(misr_cm - 1)
mod_cm = make_binary(mod_cm)

stats = []
for i in tqdm(range(500)):
    total_p = 0
    success = 0
    for x in range(64):
        for y in range(64):
            misr_p = misr_cm[i,x,y]
            if misr_p != -1:
                total_p += 1.
                if misr_p == mod_cm[i,x,y]:
                    success += 1.
    stats.append(success/total_p)

misr_cm[misr_cm==-1] = np.nan
print(np.unique(misr_cm,
                return_counts=True))

rad_1km = mod_rad
# Out:
# ['Band_1.0', 'Band_2.0', 'Band_20.0', 'Band_26.0', 'Band_27.0', 'Band_29.0', 'Band_31.0', 'Band_32.0', 'Band_35.0']
#   0%|          | 0/500 [00:00<?, ?it/s]
# (500, 9, 64, 64)
# (500, 64, 64, 9)
#   0%|          | 0/500 [00:00<?, ?it/s]
# (array([ 0.,  1., nan]), array([1302880,  655268,   89852]))

# %%
sum_p = 0
pixel_count = 0
for i, j in zip(misr_cm[400:].flatten(),mod_cm[400:].flatten()):
    if not np.isnan(i):
        pixel_count += 1
        if i==j:
            sum_p +=1
sum_p/pixel_count
# Out:
# 0.829844030435552

# %%
np.sum(misr_cm==mod_cm)/(500*64*64)
# Out:
# 0.79052978515625

# %%
rad_1km_norm = np.zeros(np.shape(rad_1km))

min_max_vals = []
for c in range(rad_1km_norm.shape[-1]):
    rad_1km_norm[:,:,:,c], c_min, c_max = norm_mm(rad_1km[:,:,:,c])
    min_max_vals.append((c_min,c_max))

# %%
cmasks_binary = misr_cm
# human_masks_binary_good = make_binary(human_masks_good)

# %% [markdown]
# # MODEL TRAINING

# %%
N=63099
def reset_seeds(reset_graph_with_backend=None):
    if reset_graph_with_backend is not None:
        K = reset_graph_with_backend
        K.clear_session()
        tf.compat.v1.reset_default_graph()
        print("KERAS AND TENSORFLOW GRAPHS RESET")  # optional

    np.random.seed(N)
    random.seed(N)
    tf.compat.v1.set_random_seed(N)
    print("RANDOM SEEDS RESET")  # optional

# %%
# shuffle
rng = np.random.default_rng(seed=N)
shuffle_indis = np.arange(0,400)
rng.shuffle(shuffle_indis)

rad_1km_norm_shuffle = np.zeros(np.shape(rad_1km_norm))
cmasks_binary_shuffle = np.zeros(np.shape(cmasks_binary))

rad_1km_norm_shuffle[0:400] = rad_1km_norm[shuffle_indis]
cmasks_binary_shuffle[0:400] = cmasks_binary[shuffle_indis]

rad_1km_norm_shuffle[400:]  = rad_1km_norm[400:]
cmasks_binary_shuffle[400:]  = cmasks_binary[400:]

rad_1km_norm = None
cmasks_binary = None

# %%
# labels_1hot = tf.one_hot(cmasks_binary,2)
# training_masks = labels_1hot
training_rad = rad_1km_norm_shuffle[0:350]
validate_rad = rad_1km_norm_shuffle[350:400]
testing_rad  = rad_1km_norm_shuffle[400: ]
training_cmask = cmasks_binary_shuffle[0:350]
validate_cmask = cmasks_binary_shuffle[350:400]
testing_cmask  = cmasks_binary_shuffle[400: ]

IMG_DIM=64
LENGTH_OF_DATASET, IMG_DIM_X, IMG_DIM_Y, NUM_OF_CHANNELS = np.shape(training_rad)
CLASSES = 2

# flattened arrays for MLP Dense and RFs
train_rad_flat = training_rad.reshape(-1, training_rad.shape[-1])
train_labels_1hot = tf.one_hot(training_cmask.reshape(-1),2)

valid_rad_flat = validate_rad.reshape(-1, validate_rad.shape[-1])
valid_labels_1hot = tf.one_hot(validate_cmask.reshape(-1),2)

test_rad_flat = testing_rad.reshape(-1, testing_rad.shape[-1])
test_labels_1hot = tf.one_hot(testing_cmask.reshape(-1),2)
# Out:
# 2024-06-19 11:31:18.171614: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-06-19 11:31:18.174438: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:82:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2024-06-19 11:31:18.174599: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-06-19 11:31:18.174710: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-06-19 11:31:18.174787: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-06-19 11:31:18.174859: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-06-19 11:31:18.174930: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-06-19 11:31:18.175005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-06-19 11:31:18.175078: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-06-19 11:31:18.175150: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-06-19 11:31:18.176614: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-06-19 11:31:18.176818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-06-19 11:31:18.176847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-06-19 11:31:18.176865: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-06-19 11:31:18.178599: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 902 MB memory) -> physical GPU (device: 0, name: TITAN RTX, pci bus id: 0000:82:00.0, compute capability: 7.5)

# %% [markdown]
# # RFs

# %%
# format data in df for RFs
train_df = pd.DataFrame(data=train_rad_flat, columns=format_bands_to_use(bands_to_use))
train_df.insert(9,"CMask", training_cmask.reshape(-1))
train_df['CMask'] = train_df['CMask'].astype(int)
test_df = pd.DataFrame(data=test_rad_flat, columns=format_bands_to_use(bands_to_use))
test_df.insert(9,"CMask", testing_cmask.reshape(-1))
test_df['CMask'] = test_df['CMask'].astype(int)
test_df
# Out:
#         Band_1.0  Band_2.0  Band_20.0  Band_26.0  Band_27.0  Band_29.0  \
# 0       0.044758  0.049615   0.508592   0.010795   0.649420   0.846491
# 1       0.048349  0.053914   0.510391   0.010681   0.648056   0.844970
# 2       0.048947  0.054849   0.515384   0.010279   0.644110   0.843450
# 3       0.045683  0.050774   0.504934   0.010337   0.644061   0.842963
# 4       0.052864  0.059522   0.498084   0.010566   0.642551   0.837854
# ...          ...       ...        ...        ...        ...        ...
# 409595  0.022293  0.023269   0.418263   0.010789   0.578291   0.831103
# 409596  0.022569  0.023582   0.419598   0.011234   0.572786   0.831164
# 409597  0.022183  0.022956   0.419134   0.011290   0.575514   0.830191
# 409598  0.022790  0.023778   0.419134   0.010343   0.571373   0.830191
# 409599  0.024006  0.025421   0.421862   0.010343   0.571373   0.830252
#
#         Band_31.0  Band_32.0  Band_35.0  CMask
# 0        0.866587   0.872557   0.905468      1
# 1        0.865685   0.871668   0.920609      1
# 2        0.865685   0.871668   0.914568      1
# 3        0.864684   0.869892   0.905390      1
# 4        0.859976   0.866239   0.912999      1
# ...           ...        ...        ...    ...
# 409595   0.862280   0.879171   0.913234      1
# 409596   0.862280   0.878282   0.917863      1
# 409597   0.861378   0.880158   0.903428      1
# 409598   0.861378   0.878381   0.911352      1
# 409599   0.860377   0.877493   0.901859      1
#
# [409600 rows x 10 columns]

# %%
rf_compact = ydf.RandomForestLearner(label="CMask", 
                                features=format_bands_to_use(bands_to_use),
                                num_trees=100,
                                random_seed=N,
                                max_depth=4
                               ).train(train_df)
rf_deep = ydf.RandomForestLearner(label="CMask", 
                                features=format_bands_to_use(bands_to_use),
                                num_trees=250,
                                random_seed=N,
                                max_depth=16
                               ).train(train_df)
rf_wide = ydf.RandomForestLearner(label="CMask", 
                                features=format_bands_to_use(bands_to_use),
                                num_trees=500,
                                random_seed=N,
                                max_depth=8
                               ).train(train_df)
# Out:
# Train model on 1433600 examples
# Model trained in 0:00:08.910125
# Train model on 1433600 examples
# Model trained in 0:00:48.397445
# Train model on 1433600 examples
# Model trained in 0:00:55.663775

# %%
models = [rf_compact,rf_deep, rf_wide]
models[0].describe()
# Out:
# <style>
#
# .tab_block .header {
#     flex-direction: row;
#     display: flex;
# }
#
# .tab_block .header .tab {
#     cursor: pointer;
#     background-color: #F6F5F5;
#     text-decoration: none;
#     text-align: center;
#     padding: 4px 12px;
#     color: black;
# }
#
# .tab_block .header .tab.selected {
#     border-bottom: 2px solid #2F80ED;
# }
#
# .tab_block .header .tab:hover {
#     text-decoration: none;
#     background-color: #DCDCDC;
# }
#
# .tab_block .body .tab_content {
#     display: none;
#     padding: 5px;
# }
#
# .tab_block .body .tab_content.selected {
#     display: block;
# }
#
# .ydf_pre {
#     font-size: medium;
# }
#
#
#
# .variable_importance {
# }
#
# .variable_importance select {
# }
#
# .variable_importance .content {
#   display: none;
# }
#
# .variable_importance .content.selected {
#   display: block;
# }
#
# .ydf_tuning_table {
#   border-collapse: collapse;
#   border: 1px solid lightgray;
# }
#
# .ydf_tuning_table th {
#   background-color: #ededed;
#   font-weight: bold;
#   text-align: left;
#   padding: 3px 4px;
#   border: 1px solid lightgray;
# }
#
# .ydf_tuning_table td {
#   text-align: right;
#   padding: 3px 4px;
#   border: 1px solid lightgray;
# }
#
# .ydf_tuning_table .best {
#   background-color: khaki;
# }
#
# </style>
#
# <script>
#
# function ydfShowTab(block_id, item) {
#     const block = document.getElementById(block_id);
#
#
#     console.log("HIDE first of:",block.getElementsByClassName("tab selected"));
#     console.log("HIDE first of:",block.getElementsByClassName("tab_content selected"));
#
#     block.getElementsByClassName("tab selected")[0].classList.remove("selected");
#     block.getElementsByClassName("tab_content selected")[0].classList.remove("selected");
#     document.getElementById(block_id + "_" + item).classList.add("selected");
#     document.getElementById(block_id + "_body_" + item).classList.add("selected");
# }
#
#
# function ydfShowVariableImportance(block_id) {
#     const block = document.getElementById(block_id);
#     const item = block.getElementsByTagName("select")[0].value;
#     block.getElementsByClassName("content selected")[0].classList.remove("selected");
#     document.getElementById(block_id + "_body_" + item).classList.add("selected");
# }
#
# </script>
#   <div class="tab_block" id="aae1-23ff-f7a6-8285"><div class="header"><a id="aae1-23ff-f7a6-8285_model" class="tab selected" onclick="ydfShowTab('aae1-23ff-f7a6-8285', 'model')">Model</a><a id="aae1-23ff-f7a6-8285_dataspec" class="tab" onclick="ydfShowTab('aae1-23ff-f7a6-8285', 'dataspec')">Dataspec</a><a id="aae1-23ff-f7a6-8285_training" class="tab" onclick="ydfShowTab('aae1-23ff-f7a6-8285', 'training')">Training</a><a id="aae1-23ff-f7a6-8285_variable_importance" class="tab" onclick="ydfShowTab('aae1-23ff-f7a6-8285', 'variable_importance')">Variable importances</a><a id="aae1-23ff-f7a6-8285_structure" class="tab" onclick="ydfShowTab('aae1-23ff-f7a6-8285', 'structure')">Structure</a></div><div class="body"><div id="aae1-23ff-f7a6-8285_body_model" class="tab_content selected"><b>Name</b> : RANDOM_FOREST<br><b>Task</b> : CLASSIFICATION<br><b>Label</b> : CMask<br><b>Features (9)</b> : Band_1.0 Band_2.0 Band_20.0 Band_26.0 Band_27.0 Band_29.0 Band_31.0 Band_32.0 Band_35.0<br><b>Weights</b> : None<br><b>Trained with tuner</b> : No<br><b>Model size</b> : 370 kB<br></div><div id="aae1-23ff-f7a6-8285_body_dataspec" class="tab_content"><pre class="ydf_pre">Number of records: 1433600
# Number of columns: 10
#
# Number of columns by type:
# 	NUMERICAL: 9 (90%)
# 	CATEGORICAL: 1 (10%)
#
# Columns:
#
# NUMERICAL: 9 (90%)
# 	0: &quot;Band_1.0&quot; NUMERICAL mean:0.117824 min:0 max:0.919382 sd:0.141601 dtype:DTYPE_FLOAT64
# 	1: &quot;Band_2.0&quot; NUMERICAL mean:0.140555 min:0 max:1 sd:0.173942 dtype:DTYPE_FLOAT64
# 	2: &quot;Band_20.0&quot; NUMERICAL mean:0.39962 min:0 max:1 sd:0.151778 dtype:DTYPE_FLOAT64
# 	3: &quot;Band_26.0&quot; NUMERICAL mean:0.0368884 min:0 max:1 sd:0.0714152 dtype:DTYPE_FLOAT64
# 	4: &quot;Band_27.0&quot; NUMERICAL mean:0.478236 min:0 max:1 sd:0.134093 dtype:DTYPE_FLOAT64
# 	5: &quot;Band_29.0&quot; NUMERICAL mean:0.684862 min:0 max:1 sd:0.198256 dtype:DTYPE_FLOAT64
# 	6: &quot;Band_31.0&quot; NUMERICAL mean:0.71832 min:0 max:1 sd:0.194286 dtype:DTYPE_FLOAT64
# 	7: &quot;Band_32.0&quot; NUMERICAL mean:0.733801 min:0 max:1 sd:0.193531 dtype:DTYPE_FLOAT64
# 	8: &quot;Band_35.0&quot; NUMERICAL mean:0.797049 min:0 max:0.990586 sd:0.154536 dtype:DTYPE_FLOAT64
#
# CATEGORICAL: 1 (10%)
# 	9: &quot;CMask&quot; CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:&quot;0&quot; 770465 (53.7434%) dtype:DTYPE_INT64
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
# </pre></div><div id="aae1-23ff-f7a6-8285_body_training" class="tab_content"><p>The following evaluation is computed on the validation or out-of-bag dataset.</p><pre class="ydf_pre">Number of predictions (without weights): 1433600
# Number of predictions (with weights): 1.4336e+06
# Task: CLASSIFICATION
# Label: CMask
#
# Accuracy: 0.890279  CI95[W][0.889849 0.890708]
# LogLoss: : 0.857862
# ErrorRate: : 0.109721
#
# Default Accuracy: : 0.537434
# Default LogLoss: : 0.690342
# Default ErrorRate: : 0.462566
#
# Confusion Table:
# truth\prediction
#             0       1
#     0  680685   89780
#     1   67516  595619
# Total: 1.4336e+06
#
# </pre><div style='display: grid; gap: 0px; grid-auto-columns: min-content;'><div style='grid-row:1 / span 1; grid-column:1 / span 1;'><script src='https://www.gstatic.com/external_hosted/plotly/plotly.min.js'></script>
# <div id="chart_aae1_23ff_f7a6_8285self_eval_item0" style="display: inline-block;" ></div>
# <script>
#   Plotly.newPlot(
#     'chart_aae1_23ff_f7a6_8285self_eval_item0',
#     [{
# x: [1,11,21,31,41,51,61,71,81,91,100],
# y: [0.889523,0.886259,0.889597,0.889094,0.890056,0.88989,0.889854,0.890197,0.889951,0.890246,0.890279],
# type: 'scatter',
# mode: 'lines',
# line: {
#   dash: 'solid',
#   width: 1
# },
# },
# ],
#     {
#       width: 600,
#       height: 400,
#       title: '',
#       showlegend: true,
#       xaxis: {
#         ticks: 'outside',
#         showgrid: true,
#         zeroline: false,
#         showline: true,
#         title: 'num trees',
#         },
#       font: {
#         size: 10,
#         },
#       yaxis: {
#         ticks: 'outside',
#         showgrid: true,
#         zeroline: false,
#         showline: true,
#         title: 'accuracy',
#         },
#       margin: {
#         l: 50,
#         r: 50,
#         b: 50,
#         t: 50,
#       },
#     },
#     {
#       modeBarButtonsToRemove: ['sendDataToCloud'],
#       displaylogo: false,displayModeBar: false,
#     }
#   );
# </script>
# </div></div></div><div id="aae1-23ff-f7a6-8285_body_variable_importance" class="tab_content"><p><a target="_blank" href="https://ydf.readthedocs.io/en/latest/cli_user_manual#variable-importances">Variable importances</a> measure the importance of an input feature for a model.</p><div id="aae1-23ff-f7a6-8285_vi" class="variable_importance"><select onchange="ydfShowVariableImportance('aae1-23ff-f7a6-8285_vi')"><option value="INV_MEAN_MIN_DEPTH">INV_MEAN_MIN_DEPTH</option><option value="NUM_AS_ROOT">NUM_AS_ROOT</option><option value="NUM_NODES">NUM_NODES</option><option value="SUM_SCORE">SUM_SCORE</option></select><div id="aae1-23ff-f7a6-8285_vi_body_INV_MEAN_MIN_DEPTH" class="content selected"><pre class="ydf_pre">    1.  &quot;Band_2.0&quot;  0.352734 ################
#     2. &quot;Band_31.0&quot;  0.338983 #############
#     3. &quot;Band_32.0&quot;  0.338123 #############
#     4. &quot;Band_29.0&quot;  0.323363 ###########
#     5.  &quot;Band_1.0&quot;  0.310800 #########
#     6. &quot;Band_26.0&quot;  0.294985 ######
#     7. &quot;Band_20.0&quot;  0.254291
#     8. &quot;Band_35.0&quot;  0.250313
# </pre></div><div id="aae1-23ff-f7a6-8285_vi_body_NUM_AS_ROOT" class="content"><pre class="ydf_pre">    1. &quot;Band_29.0&quot; 28.0

# %%
start = time.time()
eval_rf_compact = rf_compact.predict(test_df)
end = time.time()
print(f'Application time: {end-start} seconds')
CM = eval_rf_compact
CM
# Out:
# Application time: 0.6832542419433594 seconds
# array([0.9599994 , 0.9599994 , 0.9599994 , ..., 0.99999934, 0.99999934,
#        0.99999934], dtype=float32)

# %% [markdown]
# # Batch size plot

# %%
accs = np.zeros((4,250))
val_accs = np.zeros((4,250))

for i in range(1,5):  
    out = f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/MLP_batch_size/{10**(i+2)}/'
    s = f'{out}/history/hist'

    with open(s, "rb") as file_pi:
        history = pickle.load(file_pi)
    accs[i-1] = history['accuracy']
    val_accs[i-1] = history['val_accuracy']

# %%
font = {
        'size'   : 14
}
matplotlib.rc('font', **font)
plt.figure()
plt.plot(accs[0], color='red', label='1E3')
plt.plot(accs[1], color='blue', label='1E4')
plt.plot(accs[2], color='blueviolet', label='1E5')
plt.plot(accs[3], color='black', label='1E6')

plt.plot(val_accs[0], '--', color='red')
plt.plot(val_accs[1], '--', color='blue')
plt.plot(val_accs[2], '--', color='blueviolet')
plt.plot(val_accs[3], '--', color='black')
plt.ylim((.5,1.))

plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.title('MLPs Adjusting Batch Size')
plt.savefig('/data/keeling/a/jdnied2/c/MS_THESIS/Models/Plots/MLPS_batch_test.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure()
#       2 plt.plot(accs[0], color='red', label='1E3')
#       3 plt.plot(accs[1], color='blue', label='1E4')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # MLP

# %%
def nan_binary_crossentropy(y_true, y_pred):
    mask = tf.math.is_finite(y_true)
    y_true = tf.boolean_mask(y_true, mask)
    y_pred = tf.boolean_mask(y_pred, mask)
    return tf.keras.losses.binary_crossentropy(y_true, y_pred)

# %%
mlp = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(1, NUM_OF_CHANNELS)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(256, activation='sigmoid'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(CLASSES, activation='softmax')
])

reset_seeds(K)
EPOCHS = 250
BATCH_SIZE = 5*(64**2)


out = f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/'

mlp.compile(optimizer=tf.keras.optimizers.Adam(), 
            loss =  nan_binary_crossentropy,
#             loss ='sparse_categorical_crossentropy',
            metrics=['accuracy'])


checkpoint_path = os.path.join(out, 'E-{epoch:04d}')
print(f'\n {checkpoint_path} \n')
mlp.save_weights(checkpoint_path.format(epoch=0))
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,verbose=1,save_freq='epoch')

start = time.time()
model_history = mlp.fit(train_rad_flat, train_labels_1hot,
                        validation_data=(valid_rad_flat,valid_labels_1hot),
                        batch_size=BATCH_SIZE, 
                        callbacks=[cp_callback], 
                        epochs=EPOCHS, 
                        shuffle=True)
end = time.time()
print(f'Training for {EPOCHS} epochs & a batch size of {BATCH_SIZE} took :\n {end-start} seconds')

os.makedirs(name=f'{out}history',exist_ok=True)
s = f'{out}/history/hist'


with open(s, 'wb') as file_pi:
    pickle.dump(model_history.history, file_pi)

# 4vis = 1 2 3 4
# vis+IR = 1234

# remeber to save output of the training metricskeras.utils.plot_model(unet)
# Out:
# KERAS AND TENSORFLOW GRAPHS RESET
# RANDOM SEEDS RESET
#
#  /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-{epoch:04d}
#
# Epoch 1/250
# WARNING:tensorflow:Model was constructed with shape (None, 1, 9) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 9), dtype=tf.float32, name='flatten_input'), name='flatten_input', description="created by layer 'flatten_input'"), but it was called on an input with incompatible shape (20480, 9).
# 2024-05-29 20:58:40.425949: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-05-29 20:58:40.427588: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2599820000 Hz
# WARNING:tensorflow:Model was constructed with shape (None, 1, 9) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 9), dtype=tf.float32, name='flatten_input'), name='flatten_input', description="created by layer 'flatten_input'"), but it was called on an input with incompatible shape (20480, 9).
# 2024-05-29 20:58:41.197322: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 65/70 [==========================>...] - ETA: 0s - loss: 0.6435 - accuracy: 0.6634WARNING:tensorflow:Model was constructed with shape (None, 1, 9) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 9), dtype=tf.float32, name='flatten_input'), name='flatten_input', description="created by layer 'flatten_input'"), but it was called on an input with incompatible shape (20480, 9).
# 70/70 [==============================] - 4s 35ms/step - loss: 0.6384 - accuracy: 0.6664 - val_loss: 0.5219 - val_accuracy: 0.7662
#
# Epoch 00001: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0001
# 2024-05-29 20:58:44.415176: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0001/assets
# Epoch 2/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.4820 - accuracy: 0.7631 - val_loss: 0.4868 - val_accuracy: 0.7409
#
# Epoch 00002: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0002
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0002/assets
# Epoch 3/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.4698 - accuracy: 0.7634 - val_loss: 0.4762 - val_accuracy: 0.7556
#
# Epoch 00003: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0003
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0003/assets
# Epoch 4/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.4559 - accuracy: 0.7791 - val_loss: 0.4617 - val_accuracy: 0.7693
#
# Epoch 00004: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0004
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0004/assets
# Epoch 5/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.4389 - accuracy: 0.7896 - val_loss: 0.4291 - val_accuracy: 0.7971
#
# Epoch 00005: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0005
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0005/assets
# Epoch 6/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.4215 - accuracy: 0.7959 - val_loss: 0.4115 - val_accuracy: 0.8053
#
# Epoch 00006: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0006
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0006/assets
# Epoch 7/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.4128 - accuracy: 0.8009 - val_loss: 0.3975 - val_accuracy: 0.8140
#
# Epoch 00007: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0007
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0007/assets
# Epoch 8/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.4063 - accuracy: 0.8068 - val_loss: 0.3913 - val_accuracy: 0.8272
#
# Epoch 00008: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0008
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0008/assets
# Epoch 9/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.4031 - accuracy: 0.8106 - val_loss: 0.3887 - val_accuracy: 0.8400
#
# Epoch 00009: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0009
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0009/assets
# Epoch 10/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.4015 - accuracy: 0.8122 - val_loss: 0.3848 - val_accuracy: 0.8358
#
# Epoch 00010: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0010
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0010/assets
# Epoch 11/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3977 - accuracy: 0.8145 - val_loss: 0.3836 - val_accuracy: 0.8233
#
# Epoch 00011: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0011
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0011/assets
# Epoch 12/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3956 - accuracy: 0.8168 - val_loss: 0.3827 - val_accuracy: 0.8226
#
# Epoch 00012: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0012
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0012/assets
# Epoch 13/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3954 - accuracy: 0.8163 - val_loss: 0.3825 - val_accuracy: 0.8213
#
# Epoch 00013: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0013
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0013/assets
# Epoch 14/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3928 - accuracy: 0.8178 - val_loss: 0.3810 - val_accuracy: 0.8288
#
# Epoch 00014: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0014
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0014/assets
# Epoch 15/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3904 - accuracy: 0.8202 - val_loss: 0.3798 - val_accuracy: 0.8298
#
# Epoch 00015: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0015
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0015/assets
# Epoch 16/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3907 - accuracy: 0.8188 - val_loss: 0.3756 - val_accuracy: 0.8395
#
# Epoch 00016: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0016
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0016/assets
# Epoch 17/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3889 - accuracy: 0.8209 - val_loss: 0.3759 - val_accuracy: 0.8431
#
# Epoch 00017: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0017
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0017/assets
# Epoch 18/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3847 - accuracy: 0.8250 - val_loss: 0.3790 - val_accuracy: 0.8298
#
# Epoch 00018: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0018
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0018/assets
# Epoch 19/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3817 - accuracy: 0.8261 - val_loss: 0.3733 - val_accuracy: 0.8407
#
# Epoch 00019: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0019
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0019/assets
# Epoch 20/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3801 - accuracy: 0.8266 - val_loss: 0.3730 - val_accuracy: 0.8384
#
# Epoch 00020: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0020
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0020/assets
# Epoch 21/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3793 - accuracy: 0.8265 - val_loss: 0.3698 - val_accuracy: 0.8430
#
# Epoch 00021: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0021
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0021/assets
# Epoch 22/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3772 - accuracy: 0.8277 - val_loss: 0.3704 - val_accuracy: 0.8434
#
# Epoch 00022: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0022
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0022/assets
# Epoch 23/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3764 - accuracy: 0.8272 - val_loss: 0.3698 - val_accuracy: 0.8426
#
# Epoch 00023: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0023
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0023/assets
# Epoch 24/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3742 - accuracy: 0.8287 - val_loss: 0.3722 - val_accuracy: 0.8386
#
# Epoch 00024: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0024
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0024/assets
# Epoch 25/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3731 - accuracy: 0.8287 - val_loss: 0.3673 - val_accuracy: 0.8437
#
# Epoch 00025: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0025
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0025/assets
# Epoch 26/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3737 - accuracy: 0.8287 - val_loss: 0.3709 - val_accuracy: 0.8406
# Epoch 00026: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0026
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0026/assets
# Epoch 27/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3707 - accuracy: 0.8307 - val_loss: 0.3673 - val_accuracy: 0.8435
#
# Epoch 00027: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0027
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0027/assets
# Epoch 28/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3719 - accuracy: 0.8299 - val_loss: 0.3676 - val_accuracy: 0.8429
#
# Epoch 00028: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0028
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0028/assets
# Epoch 29/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3704 - accuracy: 0.8311 - val_loss: 0.3822 - val_accuracy: 0.8292
#
# Epoch 00029: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0029
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0029/assets
# Epoch 30/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3720 - accuracy: 0.8300 - val_loss: 0.3669 - val_accuracy: 0.8442
#
# Epoch 00030: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0030
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0030/assets
# Epoch 31/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3688 - accuracy: 0.8317 - val_loss: 0.3651 - val_accuracy: 0.8435
#
# Epoch 00031: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0031
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0031/assets
# Epoch 32/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3686 - accuracy: 0.8321 - val_loss: 0.3674 - val_accuracy: 0.8443
#
# Epoch 00032: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0032
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0032/assets
# Epoch 33/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3681 - accuracy: 0.8327 - val_loss: 0.3674 - val_accuracy: 0.8426
#
# Epoch 00033: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0033
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0033/assets
# Epoch 34/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3672 - accuracy: 0.8334 - val_loss: 0.3647 - val_accuracy: 0.8458
#
# Epoch 00034: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0034
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0034/assets
# Epoch 35/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3666 - accuracy: 0.8335 - val_loss: 0.3635 - val_accuracy: 0.8457
#
# Epoch 00035: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0035
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0035/assets
# Epoch 36/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3687 - accuracy: 0.8319 - val_loss: 0.3652 - val_accuracy: 0.8458
#
# Epoch 00036: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0036
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0036/assets
# Epoch 37/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3658 - accuracy: 0.8341 - val_loss: 0.3656 - val_accuracy: 0.8442
#
# Epoch 00037: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0037
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0037/assets
# Epoch 38/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3638 - accuracy: 0.8354 - val_loss: 0.3670 - val_accuracy: 0.8416
#
# Epoch 00038: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0038
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0038/assets
# Epoch 39/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3654 - accuracy: 0.8342 - val_loss: 0.3663 - val_accuracy: 0.8416
#
# Epoch 00039: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0039
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0039/assets
# Epoch 40/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3654 - accuracy: 0.8343 - val_loss: 0.3633 - val_accuracy: 0.8450
#
# Epoch 00040: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0040
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0040/assets
# Epoch 41/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3627 - accuracy: 0.8359 - val_loss: 0.3668 - val_accuracy: 0.8401
#
# Epoch 00041: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0041
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0041/assets
# Epoch 42/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3642 - accuracy: 0.8345 - val_loss: 0.3654 - val_accuracy: 0.8405
#
# Epoch 00042: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0042
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0042/assets
# Epoch 43/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3616 - accuracy: 0.8361 - val_loss: 0.3658 - val_accuracy: 0.8447
#
# Epoch 00043: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0043
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0043/assets
# Epoch 44/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3627 - accuracy: 0.8353 - val_loss: 0.3819 - val_accuracy: 0.8269
#
# Epoch 00044: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0044
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0044/assets
# Epoch 45/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3657 - accuracy: 0.8329 - val_loss: 0.3632 - val_accuracy: 0.8451
#
# Epoch 00045: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0045
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0045/assets
# Epoch 46/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3626 - accuracy: 0.8356 - val_loss: 0.3676 - val_accuracy: 0.8383
#
# Epoch 00046: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0046
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0046/assets
# Epoch 47/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3627 - accuracy: 0.8352 - val_loss: 0.3633 - val_accuracy: 0.8444
#
# Epoch 00047: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0047
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0047/assets
# Epoch 48/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3610 - accuracy: 0.8364 - val_loss: 0.3653 - val_accuracy: 0.8393
#
# Epoch 00048: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0048
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0048/assets
# Epoch 49/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3616 - accuracy: 0.8357 - val_loss: 0.3666 - val_accuracy: 0.8379
#
# Epoch 00049: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0049
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0049/assets
# Epoch 50/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3599 - accuracy: 0.8373 - val_loss: 0.3631 - val_accuracy: 0.8431
#
# Epoch 00050: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0050
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0050/assets
# Epoch 51/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3605 - accuracy: 0.8368 - val_loss: 0.3648 - val_accuracy: 0.8447
#
# Epoch 00051: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0051
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0051/assets
# Epoch 52/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3608 - accuracy: 0.8368 - val_loss: 0.3641 - val_accuracy: 0.8436
#
# Epoch 00052: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0052
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0052/assets
# Epoch 53/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3613 - accuracy: 0.8366 - val_loss: 0.3672 - val_accuracy: 0.8366
#
# Epoch 00053: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0053
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0053/assets
# Epoch 54/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3598 - accuracy: 0.8374 - val_loss: 0.3651 - val_accuracy: 0.8396
#
# Epoch 00054: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0054
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0054/assets
# Epoch 55/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3596 - accuracy: 0.8371 - val_loss: 0.3676 - val_accuracy: 0.8385
#
# Epoch 00055: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0055
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0055/assets
# Epoch 56/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3609 - accuracy: 0.8366 - val_loss: 0.3622 - val_accuracy: 0.8439
#
# Epoch 00056: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0056
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0056/assets
# Epoch 57/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3602 - accuracy: 0.8368 - val_loss: 0.3631 - val_accuracy: 0.8449
#
# Epoch 00057: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0057
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0057/assets
# Epoch 58/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3595 - accuracy: 0.8370 - val_loss: 0.3726 - val_accuracy: 0.8330
#
# Epoch 00058: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0058
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0058/assets
# Epoch 59/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3619 - accuracy: 0.8355 - val_loss: 0.3626 - val_accuracy: 0.8423
#
# Epoch 00059: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0059
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0059/assets
# Epoch 60/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3586 - accuracy: 0.8381 - val_loss: 0.3643 - val_accuracy: 0.8424
#
# Epoch 00060: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0060
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0060/assets
# Epoch 61/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3575 - accuracy: 0.8384 - val_loss: 0.3638 - val_accuracy: 0.8431
#
# Epoch 00061: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0061
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0061/assets
# Epoch 62/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3594 - accuracy: 0.8375 - val_loss: 0.3637 - val_accuracy: 0.8439
#
# Epoch 00062: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0062
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0062/assets
# Epoch 63/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3587 - accuracy: 0.8381 - val_loss: 0.3626 - val_accuracy: 0.8441
#
# Epoch 00063: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0063
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0063/assets
# Epoch 64/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.3583 - accuracy: 0.8383 - val_loss: 0.3651 - val_accuracy: 0.8398
#
# Epoch 00064: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0064
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0064/assets
# Epoch 65/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3593 - accuracy: 0.8376 - val_loss: 0.3643 - val_accuracy: 0.8398
#
# Epoch 00065: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0065
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0065/assets
# Epoch 66/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.3598 - accuracy: 0.8365 - val_loss: 0.3632 - val_accuracy: 0.8420
#
# Epoch 00066: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0066
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0066/assets
# Epoch 67/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3572 - accuracy: 0.8389 - val_loss: 0.3694 - val_accuracy: 0.8357
#
# Epoch 00067: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0067
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0067/assets
# Epoch 68/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3579 - accuracy: 0.8379 - val_loss: 0.3671 - val_accuracy: 0.8383
#
# Epoch 00068: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0068
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0068/assets
# Epoch 69/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3581 - accuracy: 0.8380 - val_loss: 0.3724 - val_accuracy: 0.8316
#
# Epoch 00069: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0069
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0069/assets
# Epoch 70/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3597 - accuracy: 0.8365 - val_loss: 0.3774 - val_accuracy: 0.8279
#
# Epoch 00070: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0070
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0070/assets
# Epoch 71/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3581 - accuracy: 0.8373 - val_loss: 0.3608 - val_accuracy: 0.8436
#
# Epoch 00071: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0071
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0071/assets
# Epoch 72/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3563 - accuracy: 0.8391 - val_loss: 0.3630 - val_accuracy: 0.8426
#
# Epoch 00072: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0072
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0072/assets
# Epoch 73/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3561 - accuracy: 0.8391 - val_loss: 0.3623 - val_accuracy: 0.8423
#
# Epoch 00073: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0073
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0073/assets
# Epoch 74/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3586 - accuracy: 0.8375 - val_loss: 0.3619 - val_accuracy: 0.8422
#
# Epoch 00074: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0074
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0074/assets
# Epoch 75/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3556 - accuracy: 0.8397 - val_loss: 0.3714 - val_accuracy: 0.8328
#
# Epoch 00075: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0075
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0075/assets
# Epoch 76/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3585 - accuracy: 0.8373 - val_loss: 0.3615 - val_accuracy: 0.8431
#
# Epoch 00076: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0076
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0076/assets
# Epoch 77/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3567 - accuracy: 0.8384 - val_loss: 0.3811 - val_accuracy: 0.8246
#
# Epoch 00077: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0077
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0077/assets
# Epoch 78/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3575 - accuracy: 0.8378 - val_loss: 0.3628 - val_accuracy: 0.8414
#
# Epoch 00078: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0078
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0078/assets
# Epoch 79/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3568 - accuracy: 0.8387 - val_loss: 0.3623 - val_accuracy: 0.8428
#
# Epoch 00079: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0079
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0079/assets
# Epoch 80/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3549 - accuracy: 0.8397 - val_loss: 0.3660 - val_accuracy: 0.8393
#
# Epoch 00080: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0080
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0080/assets
# Epoch 81/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3556 - accuracy: 0.8395 - val_loss: 0.3640 - val_accuracy: 0.8407
#
# Epoch 00081: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0081
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0081/assets
# Epoch 82/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3563 - accuracy: 0.8386 - val_loss: 0.3693 - val_accuracy: 0.8371
#
# Epoch 00082: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0082
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0082/assets
# Epoch 83/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3557 - accuracy: 0.8390 - val_loss: 0.3737 - val_accuracy: 0.8302
#
# Epoch 00083: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0083
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0083/assets
# Epoch 84/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3557 - accuracy: 0.8393 - val_loss: 0.3621 - val_accuracy: 0.8434
#
# Epoch 00084: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0084
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0084/assets
# Epoch 85/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3566 - accuracy: 0.8386 - val_loss: 0.3669 - val_accuracy: 0.8371
#
# Epoch 00085: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0085
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0085/assets
# Epoch 86/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3557 - accuracy: 0.8398 - val_loss: 0.3619 - val_accuracy: 0.8420
#
# Epoch 00086: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0086
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0086/assets
# Epoch 87/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3558 - accuracy: 0.8392 - val_loss: 0.3665 - val_accuracy: 0.8374
#
# Epoch 00087: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0087
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0087/assets
# Epoch 88/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3569 - accuracy: 0.8377 - val_loss: 0.3627 - val_accuracy: 0.8408
#
# Epoch 00088: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0088
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0088/assets
# Epoch 89/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3550 - accuracy: 0.8391 - val_loss: 0.3625 - val_accuracy: 0.8407
#
# Epoch 00089: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0089
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0089/assets
# Epoch 90/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3534 - accuracy: 0.8406 - val_loss: 0.3615 - val_accuracy: 0.8429
#
# Epoch 00090: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0090
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0090/assets
# Epoch 91/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3551 - accuracy: 0.8393 - val_loss: 0.3728 - val_accuracy: 0.8298
#
# Epoch 00091: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0091
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0091/assets
# Epoch 92/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3546 - accuracy: 0.8395 - val_loss: 0.3675 - val_accuracy: 0.8360
#
# Epoch 00092: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0092
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0092/assets
# Epoch 93/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3553 - accuracy: 0.8397 - val_loss: 0.3632 - val_accuracy: 0.8421
#
# Epoch 00093: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0093
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0093/assets
# Epoch 94/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3542 - accuracy: 0.8397 - val_loss: 0.3663 - val_accuracy: 0.8376
#
# Epoch 00094: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0094
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0094/assets
# Epoch 95/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3539 - accuracy: 0.8401 - val_loss: 0.3624 - val_accuracy: 0.8406
#
# Epoch 00095: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0095
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0095/assets
# Epoch 96/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3541 - accuracy: 0.8395 - val_loss: 0.3631 - val_accuracy: 0.8401
#
# Epoch 00096: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0096
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0096/assets
# Epoch 97/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3537 - accuracy: 0.8400 - val_loss: 0.3750 - val_accuracy: 0.8274
#
# Epoch 00097: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0097
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0097/assets
# Epoch 98/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.3583 - accuracy: 0.8364 - val_loss: 0.3639 - val_accuracy: 0.8394
#
# Epoch 00098: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0098
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0098/assets
# Epoch 99/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3532 - accuracy: 0.8403 - val_loss: 0.3638 - val_accuracy: 0.8395
#
# Epoch 00099: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0099
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0099/assets
# Epoch 100/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3524 - accuracy: 0.8409 - val_loss: 0.3655 - val_accuracy: 0.8371
#
# Epoch 00100: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0100
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0100/assets
# Epoch 101/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3533 - accuracy: 0.8404 - val_loss: 0.3621 - val_accuracy: 0.8415
#
# Epoch 00101: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0101
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0101/assets
# Epoch 102/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3524 - accuracy: 0.8407 - val_loss: 0.3626 - val_accuracy: 0.8421
#
# Epoch 00102: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0102
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0102/assets
# Epoch 103/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3525 - accuracy: 0.8406 - val_loss: 0.3619 - val_accuracy: 0.8417
#
# Epoch 00103: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0103
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0103/assets
# Epoch 104/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3541 - accuracy: 0.8402 - val_loss: 0.3608 - val_accuracy: 0.8417
#
# Epoch 00104: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0104
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0104/assets
# Epoch 105/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3534 - accuracy: 0.8401 - val_loss: 0.3682 - val_accuracy: 0.8336
#
# Epoch 00105: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0105
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0105/assets
# Epoch 106/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3519 - accuracy: 0.8412 - val_loss: 0.3610 - val_accuracy: 0.8421
#
# Epoch 00106: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0106
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0106/assets
# Epoch 107/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3529 - accuracy: 0.8409 - val_loss: 0.3604 - val_accuracy: 0.8428
#
# Epoch 00107: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0107
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0107/assets
# Epoch 108/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3514 - accuracy: 0.8416 - val_loss: 0.3607 - val_accuracy: 0.8419
#
# Epoch 00108: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0108
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0108/assets
# Epoch 109/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3513 - accuracy: 0.8414 - val_loss: 0.3644 - val_accuracy: 0.8391
#
# Epoch 00109: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0109
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0109/assets
# Epoch 110/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3523 - accuracy: 0.8408 - val_loss: 0.3615 - val_accuracy: 0.8420
#
# Epoch 00110: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0110
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0110/assets
# Epoch 111/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3556 - accuracy: 0.8382 - val_loss: 0.3618 - val_accuracy: 0.8417
#
# Epoch 00111: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0111
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0111/assets
# Epoch 112/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3519 - accuracy: 0.8410 - val_loss: 0.3631 - val_accuracy: 0.8398
#
# Epoch 00112: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0112
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0112/assets
# Epoch 113/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3555 - accuracy: 0.8379 - val_loss: 0.3667 - val_accuracy: 0.8375
#
# Epoch 00113: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0113
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0113/assets
# Epoch 114/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3508 - accuracy: 0.8421 - val_loss: 0.3635 - val_accuracy: 0.8388
#
# Epoch 00114: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0114
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0114/assets
# Epoch 115/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3528 - accuracy: 0.8401 - val_loss: 0.3604 - val_accuracy: 0.8421
#
# Epoch 00115: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0115
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0115/assets
# Epoch 116/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3539 - accuracy: 0.8393 - val_loss: 0.3597 - val_accuracy: 0.8423
#
# Epoch 00116: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0116
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0116/assets
# Epoch 117/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3516 - accuracy: 0.8415 - val_loss: 0.3667 - val_accuracy: 0.8343
#
# Epoch 00117: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0117
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0117/assets
# Epoch 118/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3533 - accuracy: 0.8398 - val_loss: 0.3664 - val_accuracy: 0.8356
#
# Epoch 00118: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0118
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0118/assets
# Epoch 119/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3531 - accuracy: 0.8400 - val_loss: 0.3608 - val_accuracy: 0.8413
#
# Epoch 00119: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0119
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0119/assets
# Epoch 120/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3511 - accuracy: 0.8412 - val_loss: 0.3616 - val_accuracy: 0.8413
#
# Epoch 00120: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0120
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0120/assets
# Epoch 121/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3512 - accuracy: 0.8415 - val_loss: 0.3593 - val_accuracy: 0.8424
#
# Epoch 00121: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0121
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0121/assets
# Epoch 122/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3526 - accuracy: 0.8405 - val_loss: 0.3737 - val_accuracy: 0.8292
#
# Epoch 00122: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0122
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0122/assets
# Epoch 123/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3533 - accuracy: 0.8397 - val_loss: 0.3609 - val_accuracy: 0.8421
#
# Epoch 00123: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0123
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0123/assets
# Epoch 124/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3499 - accuracy: 0.8424 - val_loss: 0.3613 - val_accuracy: 0.8404
#
# Epoch 00124: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0124
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0124/assets
# Epoch 125/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3517 - accuracy: 0.8409 - val_loss: 0.3751 - val_accuracy: 0.8298
# Epoch 00125: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0125
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0125/assets
# Epoch 126/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3513 - accuracy: 0.8411 - val_loss: 0.3603 - val_accuracy: 0.8416
#
# Epoch 00126: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0126
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0126/assets
# Epoch 127/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3505 - accuracy: 0.8413 - val_loss: 0.3599 - val_accuracy: 0.8417
#
# Epoch 00127: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0127
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0127/assets
# Epoch 128/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3519 - accuracy: 0.8405 - val_loss: 0.3604 - val_accuracy: 0.8421
#
# Epoch 00128: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0128
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0128/assets
# Epoch 129/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3497 - accuracy: 0.8423 - val_loss: 0.3602 - val_accuracy: 0.8418
#
# Epoch 00129: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0129
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0129/assets
# Epoch 130/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3514 - accuracy: 0.8404 - val_loss: 0.3681 - val_accuracy: 0.8314
#
# Epoch 00130: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0130
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0130/assets
# Epoch 131/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3507 - accuracy: 0.8411 - val_loss: 0.3595 - val_accuracy: 0.8425
#
# Epoch 00131: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0131
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0131/assets
# Epoch 132/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3521 - accuracy: 0.8400 - val_loss: 0.3655 - val_accuracy: 0.8346
#
# Epoch 00132: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0132
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0132/assets
# Epoch 133/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3506 - accuracy: 0.8412 - val_loss: 0.3630 - val_accuracy: 0.8379
#
# Epoch 00133: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0133
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0133/assets
# Epoch 134/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3492 - accuracy: 0.8425 - val_loss: 0.3617 - val_accuracy: 0.8401
#
# Epoch 00134: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0134
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0134/assets
# Epoch 135/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3496 - accuracy: 0.8418 - val_loss: 0.3620 - val_accuracy: 0.8405
#
# Epoch 00135: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0135
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0135/assets
# Epoch 136/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3494 - accuracy: 0.8420 - val_loss: 0.3612 - val_accuracy: 0.8409
#
# Epoch 00136: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0136
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0136/assets
# Epoch 137/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3490 - accuracy: 0.8427 - val_loss: 0.3605 - val_accuracy: 0.8418
#
# Epoch 00137: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0137
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0137/assets
# Epoch 138/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3501 - accuracy: 0.8417 - val_loss: 0.3611 - val_accuracy: 0.8417
#
# Epoch 00138: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0138
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0138/assets
# Epoch 139/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3502 - accuracy: 0.8415 - val_loss: 0.3618 - val_accuracy: 0.8404
#
# Epoch 00139: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0139
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0139/assets
# Epoch 140/250
# ...
#
# Epoch 00203: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0203
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0203/assets
# Epoch 204/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3399 - accuracy: 0.8456 - val_loss: 0.3604 - val_accuracy: 0.8440
#
# Epoch 00204: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0204
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0204/assets
# Epoch 205/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3395 - accuracy: 0.8459 - val_loss: 0.3577 - val_accuracy: 0.8433
#
# Epoch 00205: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0205
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0205/assets
# Epoch 206/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3397 - accuracy: 0.8454 - val_loss: 0.3649 - val_accuracy: 0.8384
#
# Epoch 00206: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0206
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0206/assets
# Epoch 207/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3416 - accuracy: 0.8440 - val_loss: 0.3584 - val_accuracy: 0.8436
#
# Epoch 00207: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0207
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0207/assets
# Epoch 208/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.3401 - accuracy: 0.8455 - val_loss: 0.3582 - val_accuracy: 0.8444
#
# Epoch 00208: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0208
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0208/assets
# Epoch 209/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.3405 - accuracy: 0.8451 - val_loss: 0.3593 - val_accuracy: 0.8446
#
# Epoch 00209: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0209
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0209/assets
# Epoch 210/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.3389 - accuracy: 0.8460 - val_loss: 0.3635 - val_accuracy: 0.8408
#
# Epoch 00210: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0210
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0210/assets
# Epoch 211/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.3401 - accuracy: 0.8447 - val_loss: 0.3587 - val_accuracy: 0.8444
#
# Epoch 00211: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0211
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0211/assets
# Epoch 212/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3404 - accuracy: 0.8444 - val_loss: 0.3645 - val_accuracy: 0.8400
#
# Epoch 00212: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0212
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0212/assets
# Epoch 213/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3388 - accuracy: 0.8459 - val_loss: 0.3684 - val_accuracy: 0.8352
#
# Epoch 00213: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0213
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0213/assets
# Epoch 214/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3417 - accuracy: 0.8434 - val_loss: 0.3591 - val_accuracy: 0.8451
#
# Epoch 00214: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0214
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0214/assets
# Epoch 215/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3400 - accuracy: 0.8452 - val_loss: 0.3677 - val_accuracy: 0.8378
#
# Epoch 00215: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0215
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0215/assets
# Epoch 216/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3388 - accuracy: 0.8458 - val_loss: 0.3741 - val_accuracy: 0.8316
#
# Epoch 00216: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0216
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0216/assets
# Epoch 217/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3417 - accuracy: 0.8436 - val_loss: 0.3604 - val_accuracy: 0.8433
#
# Epoch 00217: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0217
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0217/assets
# Epoch 218/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3394 - accuracy: 0.8455 - val_loss: 0.3649 - val_accuracy: 0.8334
#
# Epoch 00218: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0218
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0218/assets
# Epoch 219/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3416 - accuracy: 0.8433 - val_loss: 0.3677 - val_accuracy: 0.8366
#
# Epoch 00219: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0219
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0219/assets
# Epoch 220/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3392 - accuracy: 0.8452 - val_loss: 0.3621 - val_accuracy: 0.8420
#
# Epoch 00220: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0220
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0220/assets
# Epoch 221/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3377 - accuracy: 0.8465 - val_loss: 0.3584 - val_accuracy: 0.8442
#
# Epoch 00221: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0221
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0221/assets
# Epoch 222/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3426 - accuracy: 0.8424 - val_loss: 0.3576 - val_accuracy: 0.8457
#
# Epoch 00222: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0222
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0222/assets
# Epoch 223/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3392 - accuracy: 0.8454 - val_loss: 0.3749 - val_accuracy: 0.8322
#
# Epoch 00223: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0223
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0223/assets
# Epoch 224/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3405 - accuracy: 0.8439 - val_loss: 0.3594 - val_accuracy: 0.8426
#
# Epoch 00224: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0224
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0224/assets
# Epoch 225/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3391 - accuracy: 0.8454 - val_loss: 0.3578 - val_accuracy: 0.8458
#
# Epoch 00225: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0225
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0225/assets
# Epoch 226/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3398 - accuracy: 0.8450 - val_loss: 0.3658 - val_accuracy: 0.8374
#
# Epoch 00226: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0226
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0226/assets
# Epoch 227/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3385 - accuracy: 0.8450 - val_loss: 0.3623 - val_accuracy: 0.8451
#
# Epoch 00227: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0227
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0227/assets
# Epoch 228/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3407 - accuracy: 0.8434 - val_loss: 0.3583 - val_accuracy: 0.8450
#
# Epoch 00228: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0228
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0228/assets
# Epoch 229/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3362 - accuracy: 0.8472 - val_loss: 0.3570 - val_accuracy: 0.8459
#
# Epoch 00229: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0229
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0229/assets
# Epoch 230/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3382 - accuracy: 0.8463 - val_loss: 0.3574 - val_accuracy: 0.8457
#
# Epoch 00230: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0230
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0230/assets
# Epoch 231/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3376 - accuracy: 0.8466 - val_loss: 0.3595 - val_accuracy: 0.8440
#
# Epoch 00231: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0231
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0231/assets
# Epoch 232/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3365 - accuracy: 0.8471 - val_loss: 0.3694 - val_accuracy: 0.8354
#
# Epoch 00232: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0232
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0232/assets
# Epoch 233/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3384 - accuracy: 0.8458 - val_loss: 0.3621 - val_accuracy: 0.8373
#
# Epoch 00233: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0233
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0233/assets
# Epoch 234/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3370 - accuracy: 0.8468 - val_loss: 0.3595 - val_accuracy: 0.8460
#
# Epoch 00234: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0234
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0234/assets
# Epoch 235/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3363 - accuracy: 0.8469 - val_loss: 0.3603 - val_accuracy: 0.8441
#
# Epoch 00235: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0235
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0235/assets
# Epoch 236/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3373 - accuracy: 0.8466 - val_loss: 0.3601 - val_accuracy: 0.8462
#
# Epoch 00236: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0236
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0236/assets
# Epoch 237/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3369 - accuracy: 0.8464 - val_loss: 0.3643 - val_accuracy: 0.8336
#
# Epoch 00237: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0237
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0237/assets
# Epoch 238/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3397 - accuracy: 0.8445 - val_loss: 0.3585 - val_accuracy: 0.8454
#
# Epoch 00238: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0238
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0238/assets
# Epoch 239/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3366 - accuracy: 0.8468 - val_loss: 0.3670 - val_accuracy: 0.8307
#
# Epoch 00239: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0239
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0239/assets
# Epoch 240/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3411 - accuracy: 0.8428 - val_loss: 0.3588 - val_accuracy: 0.8453
#
# Epoch 00240: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0240
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0240/assets
# Epoch 241/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3357 - accuracy: 0.8477 - val_loss: 0.3590 - val_accuracy: 0.8448
#
# Epoch 00241: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0241
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0241/assets
# Epoch 242/250
# 70/70 [==============================] - 0s 6ms/step - loss: 0.3377 - accuracy: 0.8460 - val_loss: 0.3596 - val_accuracy: 0.8457
#
# Epoch 00242: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0242
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0242/assets
# Epoch 243/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3357 - accuracy: 0.8470 - val_loss: 0.3605 - val_accuracy: 0.8438
#
# Epoch 00243: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0243
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0243/assets
# Epoch 244/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3393 - accuracy: 0.8439 - val_loss: 0.3656 - val_accuracy: 0.8333
#
# Epoch 00244: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0244
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0244/assets
# Epoch 245/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3392 - accuracy: 0.8440 - val_loss: 0.3781 - val_accuracy: 0.8298
#
# Epoch 00245: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0245
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0245/assets
# Epoch 246/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3398 - accuracy: 0.8440 - val_loss: 0.3589 - val_accuracy: 0.8470
#
# Epoch 00246: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0246
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0246/assets
# Epoch 247/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3355 - accuracy: 0.8475 - val_loss: 0.3579 - val_accuracy: 0.8474
#
# Epoch 00247: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0247
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0247/assets
# Epoch 248/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3359 - accuracy: 0.8470 - val_loss: 0.3654 - val_accuracy: 0.8419
#
# Epoch 00248: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0248
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0248/assets
# Epoch 249/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3354 - accuracy: 0.8473 - val_loss: 0.3634 - val_accuracy: 0.8372
#
# Epoch 00249: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0249
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0249/assets
# Epoch 250/250
# 70/70 [==============================] - 0s 5ms/step - loss: 0.3354 - accuracy: 0.8474 - val_loss: 0.3617 - val_accuracy: 0.8440
#
# Epoch 00250: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0250
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/E-0250/assets
# Training for 250 epochs & a batch size of 20480 took :
#  261.88082575798035 seconds

# %%
with open(s, "rb") as file_pi:
    history = pickle.load(file_pi)
accs = history['accuracy']
val_accs = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']

plt.figure()
plt.plot(accs, color='red', label='acc')
plt.plot(val_accs, color='blue', label='val acc')

plt.ylim((.5,1.))

plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.title('Acc. v.s. Epoch')

plt.figure()
plt.plot(loss, color='red', label='loss')
plt.plot(val_loss, color='blue', label='val_loss')

plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.title('Loss v.s. Epoch')
# plt.savefig('/data/keeling/a/jdnied2/c/MS_THESIS/Models/Plots/MLPS_batch_test.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Loss v.s. Epoch')

# %%
mlp = tf.keras.models.load_model(f'{out}/E-0250/', 
                                 compile=False)
start = time.time()
output = mlp.predict(test_rad_flat)
end = time.time()
print(end-start)
output
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 1, 9) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 9), dtype=tf.float32, name='flatten_input'), name='flatten_input', description="created by layer 'flatten_input'"), but it was called on an input with incompatible shape (32, 9).
# 7.34893012046814
# array([[0.5966486 , 0.40335143],
#        [0.74913347, 0.2508665 ],
#        [0.6682942 , 0.33170575],
#        ...,
#        [0.46384463, 0.53615534],
#        [0.5114707 , 0.4885293 ],
#        [0.55744314, 0.44255686]], dtype=float32)

# %%
CM = np.zeros((2,2))
@jit(nopython=True)                         
def CM_G_flat(predictions, truth, CM):
    output_new = []
    count_pixels = 0
    ML_layer_0=predictions[:,0]
    ML_layer_1=predictions[:,1]
 
    for i in range(predictions.shape[0]):
        if predictions[i,0] > predictions[i,1]:
                p = 0
        else:
                p = 1
                
        if not np.isnan(truth[i,0]) and not np.isnan(truth[i,1]):
            count_pixels+=1
            if truth[i,0] > truth[i,1]:
                    t = 0
            else:
                    t = 1
            output_new.append(p)
            CM[p,t] += 1
    return CM, np.array(output_new),count_pixels

CM,output_ims,num_pixels = CM_G_flat(output, test_labels_1hot, CM)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 25
#      22             CM[p,t] += 1
#      23     return CM, np.array(output_new),count_pixels
# ---> 25 CM,output_ims,num_pixels = CM_G_flat(output, test_labels_1hot, CM)
#
# NameError: name 'output' is not defined

# %%
percent = (CM/num_pixels)*100
percent
# Out:
# array([[56.47216797,  9.28271484],
#        [ 7.70825195, 26.53686523]])

# %%
percent[0,0]+percent[1,1]
# Out:
# 83.009033203125

# %%
# look at example output
CM,output_ims,num_pixels = CM_G_flat(output, test_labels_1hot, CM)
output_reshaped = np.reshape(output_ims,(100,64,64))
plt.figure()
plt.imshow(output_reshaped[40])
plt.imshow(testing_cmask[40])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # CNNs

# %%
def cnn_simple(input_size=(IMG_DIM, IMG_DIM, NUM_OF_CHANNELS), 
               n_filters=64, n_classes=2):
    inputs = Input(input_size)
    conv = Conv2D(n_filters, 
                  kernel_size = 3,     
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(inputs)
    conv = Conv2D(n_filters*2, 
                  kernel_size = 3,     
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(conv)
    conv = Conv2D(n_filters*4, 
                  kernel_size = 3,     
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(conv)
    conv = Conv2D(n_filters*8, 
                  kernel_size = 3,     
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(conv)
    conv = Conv2D(n_classes,
                 1,
                 activation='relu',
                 padding='same',
                 kernel_initializer='he_normal')(conv)
    
    conv_out = Activation('softmax')(conv)

    model = tf.keras.Model(inputs=inputs, outputs=conv_out)

    return model

# %%
def down_block(inputs=None, n_kernels=32, k_size=3, 
               dropout_prob=0, add_max_pooling=True):
    
    conv = Conv2D(n_kernels, 
                  kernel_size = k_size,     
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(inputs)
    
    conv = Conv2D(n_kernels, 
                  kernel_size = k_size, 
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(conv)
   
    

    if dropout_prob > 0:
        conv = Dropout(dropout_prob)(conv)
        
    if add_max_pooling:
        next_layer = MaxPooling2D(pool_size=(2,2))(conv)      
    else:
        next_layer = conv
        
    #conv = BatchNormalization()(conv)
    skip_connection = conv
    
    return next_layer, skip_connection

# %%
def up_block(expansive_input, concat_input, n_kernels=32, k_size=3):
    
    up = Conv2DTranspose(
                 n_kernels,  
                 kernel_size = 3,
                 strides=(2,2),
                 padding='same')(expansive_input)
    
    merge = concatenate([up, concat_input], axis=3)
    conv = Conv2D(n_kernels,  
                 kernel_size = k_size,   
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(merge)
    conv = Conv2D(n_kernels,  
                 kernel_size = k_size,  
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(conv)
    
    return conv

# %%
def unet_model(input_size=(IMG_DIM_X, IMG_DIM_Y, NUM_OF_CHANNELS), 
               n_kernels=32, n_classes=4):
    
    inputs = Input(input_size)
    
    # Encoding (contract) path
    cblock1 = down_block(inputs,       n_kernels)
    cblock2 = down_block(cblock1[0], 2*n_kernels)
    cblock3 = down_block(cblock2[0], 4*n_kernels)
    cblock4 = down_block(cblock3[0], 8*n_kernels, dropout_prob=0.2) 
    cblock5 = down_block(cblock4[0],16*n_kernels, dropout_prob=0.2, add_max_pooling=None)     
    
    # Decoding (expand) path
    ublock6 = up_block(cblock5[0], cblock4[1], 8*n_kernels)
    ublock7 = up_block(ublock6,    cblock3[1], 4*n_kernels)
    ublock8 = up_block(ublock7,    cblock2[1], 2*n_kernels)
    ublock9 = up_block(ublock8,    cblock1[1],   n_kernels)

    conv9 = Conv2D(n_classes,
                 1,
                 activation='relu',
                 padding='same',
                 kernel_initializer='he_normal')(ublock9)
    
    conv10 = Conv2D(n_classes, kernel_size=1, padding='same', activation = 'softmax')(conv9) 
    conv10 = Activation('softmax')(conv9)

    unet = tf.keras.Model(inputs=inputs, outputs=conv10)

    return unet

# %%
training_cmask.shape
# Out:
# (350, 64, 64)

# %%
reset_seeds(K)

out = f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/'

EPOCHS = 250

cnn = cnn_simple((IMG_DIM, IMG_DIM, NUM_OF_CHANNELS), n_classes=2)

cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
#             loss =  tf.keras.losses.BinaryCrossentropy(from_logits=True),
            loss = nan_binary_crossentropy,
#             loss ='sparse_categorical_crossentropy',
            metrics=['accuracy'])


checkpoint_path = os.path.join(out, 'E-{epoch:04d}')
print(f'\n {checkpoint_path} \n')
cnn.save_weights(checkpoint_path.format(epoch=0))
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,verbose=1,save_freq='epoch')

model_history = cnn.fit(training_rad, tf.one_hot(training_cmask,2),
                        validation_data=(validate_rad,tf.one_hot(validate_cmask,2)),
                        batch_size=5, callbacks=[cp_callback], epochs=EPOCHS)

os.makedirs(name=f'{out}history',exist_ok=True)
s = f'{out}/history/hist'


with open(s, 'wb') as file_pi:
    pickle.dump(model_history.history, file_pi)
# 4vis = 1 2 3 4
# vis+IR = 1234

# remeber to save output of the training metricskeras.utils.plot_model(unet)
# Out:
# KERAS AND TENSORFLOW GRAPHS RESET
# RANDOM SEEDS RESET
#
#  /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-{epoch:04d}
#
# Epoch 1/250
# 2024-05-29 21:12:28.263382: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-05-29 21:12:30.574795: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2024-05-29 21:12:30.636119: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 70/70 [==============================] - 14s 17ms/step - loss: 0.6033 - accuracy: 0.6804 - val_loss: 0.5706 - val_accuracy: 0.6194
#
# Epoch 00001: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0001
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0001/assets
# Epoch 2/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.5238 - accuracy: 0.6880 - val_loss: 0.5302 - val_accuracy: 0.6194
#
# Epoch 00002: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0002
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0002/assets
# Epoch 3/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4908 - accuracy: 0.6833 - val_loss: 0.5621 - val_accuracy: 0.6194
#
# Epoch 00003: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0003
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0003/assets
# Epoch 4/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.5262 - accuracy: 0.6824 - val_loss: 0.5149 - val_accuracy: 0.6194
#
# Epoch 00004: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0004
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0004/assets
# Epoch 5/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4848 - accuracy: 0.6901 - val_loss: 0.5273 - val_accuracy: 0.6194
#
# Epoch 00005: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0005
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0005/assets
# Epoch 6/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4822 - accuracy: 0.7086 - val_loss: 0.5462 - val_accuracy: 0.6194
#
# Epoch 00006: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0006
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0006/assets
# Epoch 7/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4764 - accuracy: 0.7024 - val_loss: 0.5177 - val_accuracy: 0.6194
#
# Epoch 00007: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0007
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0007/assets
# Epoch 8/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4691 - accuracy: 0.6900 - val_loss: 0.5443 - val_accuracy: 0.6194
#
# Epoch 00008: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0008
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0008/assets
# Epoch 9/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4776 - accuracy: 0.6763 - val_loss: 0.4985 - val_accuracy: 0.6194
#
# Epoch 00009: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0009
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0009/assets
# Epoch 10/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4509 - accuracy: 0.6978 - val_loss: 0.5116 - val_accuracy: 0.6194
#
# Epoch 00010: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0010
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0010/assets
# Epoch 11/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4435 - accuracy: 0.7084 - val_loss: 0.5028 - val_accuracy: 0.6196
#
# Epoch 00011: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0011
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0011/assets
# Epoch 12/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4597 - accuracy: 0.6947 - val_loss: 0.4899 - val_accuracy: 0.6194
#
# Epoch 00012: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0012
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0012/assets
# Epoch 13/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4555 - accuracy: 0.6995 - val_loss: 0.5467 - val_accuracy: 0.6193
#
# Epoch 00013: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0013
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0013/assets
# Epoch 14/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4862 - accuracy: 0.7079 - val_loss: 0.5004 - val_accuracy: 0.6194
#
# Epoch 00014: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0014
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0014/assets
# Epoch 15/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4547 - accuracy: 0.6987 - val_loss: 0.4953 - val_accuracy: 0.6194
#
# Epoch 00015: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0015
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0015/assets
# Epoch 16/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4623 - accuracy: 0.6816 - val_loss: 0.5128 - val_accuracy: 0.6196
#
# Epoch 00016: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0016
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0016/assets
# Epoch 17/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4635 - accuracy: 0.7001 - val_loss: 0.4894 - val_accuracy: 0.6194
#
# Epoch 00017: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0017
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0017/assets
# Epoch 18/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4639 - accuracy: 0.6761 - val_loss: 0.5101 - val_accuracy: 0.6198
#
# Epoch 00018: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0018
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0018/assets
# Epoch 19/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4637 - accuracy: 0.6891 - val_loss: 0.5220 - val_accuracy: 0.6193
#
# Epoch 00019: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0019
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0019/assets
# Epoch 20/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4696 - accuracy: 0.6908 - val_loss: 0.4935 - val_accuracy: 0.6194
#
# Epoch 00020: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0020
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0020/assets
# Epoch 21/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4721 - accuracy: 0.6940 - val_loss: 0.4968 - val_accuracy: 0.6194
#
# Epoch 00021: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0021
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0021/assets
# Epoch 22/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4468 - accuracy: 0.6945 - val_loss: 0.4853 - val_accuracy: 0.6194
#
# Epoch 00022: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0022
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0022/assets
# Epoch 23/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4542 - accuracy: 0.6966 - val_loss: 0.4972 - val_accuracy: 0.6194
#
# Epoch 00023: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0023
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0023/assets
# Epoch 24/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4462 - accuracy: 0.6953 - val_loss: 0.4795 - val_accuracy: 0.6196
#
# Epoch 00024: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0024
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0024/assets
# Epoch 25/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4519 - accuracy: 0.6961 - val_loss: 0.4850 - val_accuracy: 0.6194
#
# Epoch 00025: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0025
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0025/assets
# Epoch 26/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.4569 - accuracy: 0.6796 - val_loss: 0.4985 - val_accuracy: 0.6194
#
# Epoch 00026: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0026
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0026/assets
# Epoch 27/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4352 - accuracy: 0.7093 - val_loss: 0.4836 - val_accuracy: 0.6198
#
# Epoch 00027: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0027
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0027/assets
# Epoch 28/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4551 - accuracy: 0.6699 - val_loss: 0.4749 - val_accuracy: 0.6197
#
# Epoch 00028: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0028
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0028/assets
# Epoch 29/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4288 - accuracy: 0.7035 - val_loss: 0.5337 - val_accuracy: 0.6193
#
# Epoch 00029: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0029
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0029/assets
# Epoch 30/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4503 - accuracy: 0.7067 - val_loss: 0.4774 - val_accuracy: 0.6199
#
# Epoch 00030: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0030
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0030/assets
# Epoch 31/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4435 - accuracy: 0.6960 - val_loss: 0.4797 - val_accuracy: 0.6197
#
# Epoch 00031: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0031
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0031/assets
# Epoch 32/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4512 - accuracy: 0.6867 - val_loss: 0.4727 - val_accuracy: 0.6203
#
# Epoch 00032: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0032
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0032/assets
# Epoch 33/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4382 - accuracy: 0.6796 - val_loss: 0.4809 - val_accuracy: 0.6196
#
# Epoch 00033: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0033
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0033/assets
# Epoch 34/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.4483 - accuracy: 0.6934 - val_loss: 0.4831 - val_accuracy: 0.6196
#
# Epoch 00034: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0034
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0034/assets
# Epoch 35/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.4264 - accuracy: 0.6963 - val_loss: 0.4804 - val_accuracy: 0.6194
#
# Epoch 00035: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0035
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0035/assets
# Epoch 36/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4469 - accuracy: 0.6680 - val_loss: 0.4909 - val_accuracy: 0.6197
#
# Epoch 00036: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0036
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0036/assets
# Epoch 37/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.4438 - accuracy: 0.6818 - val_loss: 0.4968 - val_accuracy: 0.6194
#
# Epoch 00037: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0037
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0037/assets
# Epoch 38/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.4350 - accuracy: 0.7082 - val_loss: 0.4788 - val_accuracy: 0.6194
#
# Epoch 00038: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0038
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0038/assets
# Epoch 39/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.4329 - accuracy: 0.7024 - val_loss: 0.4721 - val_accuracy: 0.6198
#
# Epoch 00039: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0039
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0039/assets
# Epoch 40/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.4607 - accuracy: 0.6672 - val_loss: 0.4740 - val_accuracy: 0.6196
#
# Epoch 00040: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0040
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0040/assets
# Epoch 41/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4542 - accuracy: 0.6669 - val_loss: 0.4438 - val_accuracy: 0.7800
#
# Epoch 00041: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0041
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0041/assets
# Epoch 42/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3988 - accuracy: 0.8042 - val_loss: 0.4031 - val_accuracy: 0.8118
#
# Epoch 00042: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0042
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0042/assets
# Epoch 43/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3920 - accuracy: 0.7999 - val_loss: 0.3684 - val_accuracy: 0.8146
#
# Epoch 00043: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0043
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0043/assets
# Epoch 44/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3896 - accuracy: 0.8138 - val_loss: 0.3685 - val_accuracy: 0.8295
#
# Epoch 00044: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0044
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0044/assets
# Epoch 45/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3737 - accuracy: 0.8092 - val_loss: 0.3796 - val_accuracy: 0.8244
#
# Epoch 00045: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0045
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0045/assets
# Epoch 46/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3962 - accuracy: 0.8227 - val_loss: 0.3609 - val_accuracy: 0.8334
#
# Epoch 00046: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0046
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0046/assets
# Epoch 47/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3759 - accuracy: 0.8339 - val_loss: 0.3782 - val_accuracy: 0.8313
#
# Epoch 00047: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0047
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0047/assets
# Epoch 48/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3921 - accuracy: 0.8098 - val_loss: 0.3848 - val_accuracy: 0.8366
#
# Epoch 00048: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0048
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0048/assets
# Epoch 49/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3884 - accuracy: 0.8158 - val_loss: 0.3671 - val_accuracy: 0.8350
#
# Epoch 00049: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0049
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0049/assets
# Epoch 50/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3861 - accuracy: 0.8088 - val_loss: 0.3551 - val_accuracy: 0.8485
# Epoch 00050: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0050
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0050/assets
# Epoch 51/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3567 - accuracy: 0.8337 - val_loss: 0.4021 - val_accuracy: 0.8256
#
# Epoch 00051: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0051
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0051/assets
# Epoch 52/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3763 - accuracy: 0.8200 - val_loss: 0.3870 - val_accuracy: 0.8275
#
# Epoch 00052: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0052
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0052/assets
# Epoch 53/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3794 - accuracy: 0.8264 - val_loss: 0.3596 - val_accuracy: 0.8457
#
# Epoch 00053: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0053
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0053/assets
# Epoch 54/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3502 - accuracy: 0.8459 - val_loss: 0.3786 - val_accuracy: 0.8386
#
# Epoch 00054: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0054
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0054/assets
# Epoch 55/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3755 - accuracy: 0.8178 - val_loss: 0.3551 - val_accuracy: 0.8404
#
# Epoch 00055: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0055
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0055/assets
# Epoch 56/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3566 - accuracy: 0.8330 - val_loss: 0.3645 - val_accuracy: 0.8555
#
# Epoch 00056: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0056
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0056/assets
# Epoch 57/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3598 - accuracy: 0.8348 - val_loss: 0.3514 - val_accuracy: 0.8527
#
# Epoch 00057: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0057
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0057/assets
# Epoch 58/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3461 - accuracy: 0.8431 - val_loss: 0.3431 - val_accuracy: 0.8563
#
# Epoch 00058: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0058
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0058/assets
# Epoch 59/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3509 - accuracy: 0.8325 - val_loss: 0.3569 - val_accuracy: 0.8394
#
# Epoch 00059: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0059
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0059/assets
# Epoch 60/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3436 - accuracy: 0.8462 - val_loss: 0.3445 - val_accuracy: 0.8536
#
# Epoch 00060: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0060
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0060/assets
# Epoch 61/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3284 - accuracy: 0.8565 - val_loss: 0.3698 - val_accuracy: 0.8334
#
# Epoch 00061: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0061
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0061/assets
# Epoch 62/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3623 - accuracy: 0.8414 - val_loss: 0.3676 - val_accuracy: 0.8504
#
# Epoch 00062: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0062
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0062/assets
# Epoch 63/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3337 - accuracy: 0.8536 - val_loss: 0.3587 - val_accuracy: 0.8363
#
# Epoch 00063: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0063
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0063/assets
# Epoch 64/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3510 - accuracy: 0.8381 - val_loss: 0.3470 - val_accuracy: 0.8519
#
# Epoch 00064: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0064
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0064/assets
# Epoch 65/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3342 - accuracy: 0.8563 - val_loss: 0.3557 - val_accuracy: 0.8598
#
# Epoch 00065: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0065
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0065/assets
# Epoch 66/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3540 - accuracy: 0.8521 - val_loss: 0.3478 - val_accuracy: 0.8596
#
# Epoch 00066: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0066
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0066/assets
# Epoch 67/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3527 - accuracy: 0.8370 - val_loss: 0.3391 - val_accuracy: 0.8536
#
# Epoch 00067: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0067
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0067/assets
# Epoch 68/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3364 - accuracy: 0.8531 - val_loss: 0.3455 - val_accuracy: 0.8574
#
# Epoch 00068: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0068
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0068/assets
# Epoch 69/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3148 - accuracy: 0.8633 - val_loss: 0.3397 - val_accuracy: 0.8532
#
# Epoch 00069: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0069
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0069/assets
# Epoch 70/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3476 - accuracy: 0.8462 - val_loss: 0.3476 - val_accuracy: 0.8467
#
# Epoch 00070: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0070
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0070/assets
# Epoch 71/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3376 - accuracy: 0.8474 - val_loss: 0.3330 - val_accuracy: 0.8603
#
# Epoch 00071: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0071
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0071/assets
# Epoch 72/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3398 - accuracy: 0.8503 - val_loss: 0.3466 - val_accuracy: 0.8462
#
# Epoch 00072: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0072
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0072/assets
# Epoch 73/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3455 - accuracy: 0.8372 - val_loss: 0.3454 - val_accuracy: 0.8490
#
# Epoch 00073: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0073
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0073/assets
# Epoch 74/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3444 - accuracy: 0.8510 - val_loss: 0.3808 - val_accuracy: 0.8346
#
# Epoch 00074: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0074
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0074/assets
# Epoch 75/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3358 - accuracy: 0.8567 - val_loss: 0.3600 - val_accuracy: 0.8377
#
# Epoch 00075: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0075
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0075/assets
# Epoch 76/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3243 - accuracy: 0.8607 - val_loss: 0.3368 - val_accuracy: 0.8553
#
# Epoch 00076: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0076
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0076/assets
# Epoch 77/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3260 - accuracy: 0.8622 - val_loss: 0.3528 - val_accuracy: 0.8642
#
# Epoch 00077: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0077
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0077/assets
# Epoch 78/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3264 - accuracy: 0.8601 - val_loss: 0.3903 - val_accuracy: 0.8265
#
# Epoch 00078: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0078
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0078/assets
# Epoch 79/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3279 - accuracy: 0.8645 - val_loss: 0.3360 - val_accuracy: 0.8570
#
# Epoch 00079: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0079
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0079/assets
# Epoch 80/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3471 - accuracy: 0.8557 - val_loss: 0.3452 - val_accuracy: 0.8479
#
# Epoch 00080: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0080
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0080/assets
# Epoch 81/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3074 - accuracy: 0.8700 - val_loss: 0.3478 - val_accuracy: 0.8436
#
# Epoch 00081: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0081
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0081/assets
# Epoch 82/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3190 - accuracy: 0.8570 - val_loss: 0.3411 - val_accuracy: 0.8574
#
# Epoch 00082: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0082
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0082/assets
# Epoch 83/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3139 - accuracy: 0.8643 - val_loss: 0.3338 - val_accuracy: 0.8662
#
# Epoch 00083: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0083
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0083/assets
# Epoch 84/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3488 - accuracy: 0.8415 - val_loss: 0.3445 - val_accuracy: 0.8564
#
# Epoch 00084: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0084
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0084/assets
# Epoch 85/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3435 - accuracy: 0.8582 - val_loss: 0.3304 - val_accuracy: 0.8654
#
# Epoch 00085: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0085
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0085/assets
# Epoch 86/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3633 - accuracy: 0.8282 - val_loss: 0.3452 - val_accuracy: 0.8448
#
# Epoch 00086: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0086
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0086/assets
# Epoch 87/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3320 - accuracy: 0.8489 - val_loss: 0.3315 - val_accuracy: 0.8674
#
# Epoch 00087: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0087
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0087/assets
# Epoch 88/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3161 - accuracy: 0.8566 - val_loss: 0.3265 - val_accuracy: 0.8626
#
# Epoch 00088: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0088
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0088/assets
# Epoch 89/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2980 - accuracy: 0.8800 - val_loss: 0.3438 - val_accuracy: 0.8496
#
# Epoch 00089: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0089
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0089/assets
# Epoch 90/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3141 - accuracy: 0.8711 - val_loss: 0.3251 - val_accuracy: 0.8644
#
# Epoch 00090: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0090
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0090/assets
# Epoch 91/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3030 - accuracy: 0.8680 - val_loss: 0.3285 - val_accuracy: 0.8584
#
# Epoch 00091: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0091
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0091/assets
# Epoch 92/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2992 - accuracy: 0.8801 - val_loss: 0.3360 - val_accuracy: 0.8564
#
# Epoch 00092: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0092
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0092/assets
# Epoch 93/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3222 - accuracy: 0.8670 - val_loss: 0.3287 - val_accuracy: 0.8629
#
# Epoch 00093: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0093
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0093/assets
# Epoch 94/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3132 - accuracy: 0.8714 - val_loss: 0.3249 - val_accuracy: 0.8640
#
# Epoch 00094: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0094
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0094/assets
# Epoch 95/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3209 - accuracy: 0.8653 - val_loss: 0.3358 - val_accuracy: 0.8697
#
# Epoch 00095: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0095
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0095/assets
# Epoch 96/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3125 - accuracy: 0.8706 - val_loss: 0.3371 - val_accuracy: 0.8686
#
# Epoch 00096: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0096
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0096/assets
# Epoch 97/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3070 - accuracy: 0.8717 - val_loss: 0.3297 - val_accuracy: 0.8723
#
# Epoch 00097: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0097
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0097/assets
# Epoch 98/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3020 - accuracy: 0.8786 - val_loss: 0.3482 - val_accuracy: 0.8627
#
# Epoch 00098: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0098
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0098/assets
# Epoch 99/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3116 - accuracy: 0.8776 - val_loss: 0.3312 - val_accuracy: 0.8610
#
# Epoch 00099: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0099
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0099/assets
# Epoch 100/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3026 - accuracy: 0.8763 - val_loss: 0.3563 - val_accuracy: 0.8579
#
# Epoch 00100: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0100
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0100/assets
# Epoch 101/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3107 - accuracy: 0.8750 - val_loss: 0.3332 - val_accuracy: 0.8693
#
# Epoch 00101: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0101
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0101/assets
# Epoch 102/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3050 - accuracy: 0.8801 - val_loss: 0.3299 - val_accuracy: 0.8732
#
# Epoch 00102: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0102
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0102/assets
# Epoch 103/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2790 - accuracy: 0.8904 - val_loss: 0.3267 - val_accuracy: 0.8712
#
# Epoch 00103: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0103
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0103/assets
# Epoch 104/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3000 - accuracy: 0.8771 - val_loss: 0.3553 - val_accuracy: 0.8414
#
# Epoch 00104: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0104
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0104/assets
# Epoch 105/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3067 - accuracy: 0.8706 - val_loss: 0.3280 - val_accuracy: 0.8635
#
# Epoch 00105: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0105
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0105/assets
# Epoch 106/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2887 - accuracy: 0.8823 - val_loss: 0.3260 - val_accuracy: 0.8733
#
# Epoch 00106: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0106
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0106/assets
# Epoch 107/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2955 - accuracy: 0.8782 - val_loss: 0.3197 - val_accuracy: 0.8714
#
# Epoch 00107: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0107
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0107/assets
# Epoch 108/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3139 - accuracy: 0.8695 - val_loss: 0.3295 - val_accuracy: 0.8731
#
# Epoch 00108: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0108
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0108/assets
# Epoch 109/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3018 - accuracy: 0.8768 - val_loss: 0.3312 - val_accuracy: 0.8623
#
# Epoch 00109: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0109
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0109/assets
# Epoch 110/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3095 - accuracy: 0.8764 - val_loss: 0.3451 - val_accuracy: 0.8674
#
# Epoch 00110: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0110
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0110/assets
# Epoch 111/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3178 - accuracy: 0.8712 - val_loss: 0.3230 - val_accuracy: 0.8727
#
# Epoch 00111: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0111
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0111/assets
# Epoch 112/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3032 - accuracy: 0.8809 - val_loss: 0.3215 - val_accuracy: 0.8711
#
# Epoch 00112: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0112
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0112/assets
# Epoch 113/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2959 - accuracy: 0.8854 - val_loss: 0.3274 - val_accuracy: 0.8637
#
# Epoch 00113: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0113
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0113/assets
# Epoch 114/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3124 - accuracy: 0.8696 - val_loss: 0.3245 - val_accuracy: 0.8675
#
# Epoch 00114: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0114
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0114/assets
# Epoch 115/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3143 - accuracy: 0.8740 - val_loss: 0.3370 - val_accuracy: 0.8709
#
# Epoch 00115: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0115
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0115/assets
# Epoch 116/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2887 - accuracy: 0.8807 - val_loss: 0.3184 - val_accuracy: 0.8737
#
# Epoch 00116: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0116
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0116/assets
# Epoch 117/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2809 - accuracy: 0.8870 - val_loss: 0.3221 - val_accuracy: 0.8717
#
# Epoch 00117: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0117
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0117/assets
# Epoch 118/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.3063 - accuracy: 0.8780 - val_loss: 0.3179 - val_accuracy: 0.8727
#
# Epoch 00118: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0118
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0118/assets
# Epoch 119/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2878 - accuracy: 0.8806 - val_loss: 0.3174 - val_accuracy: 0.8696
#
# Epoch 00119: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0119
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0119/assets
# Epoch 120/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2784 - accuracy: 0.8902 - val_loss: 0.3200 - val_accuracy: 0.8747
#
# Epoch 00120: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0120
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0120/assets
# Epoch 121/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3040 - accuracy: 0.8697 - val_loss: 0.3236 - val_accuracy: 0.8696
#
# Epoch 00121: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0121
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0121/assets
# Epoch 122/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2760 - accuracy: 0.8898 - val_loss: 0.3339 - val_accuracy: 0.8654
#
# Epoch 00122: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0122
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0122/assets
# Epoch 123/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2920 - accuracy: 0.8849 - val_loss: 0.3176 - val_accuracy: 0.8724
#
# Epoch 00123: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0123
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0123/assets
# Epoch 124/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2871 - accuracy: 0.8871 - val_loss: 0.3195 - val_accuracy: 0.8737
#
# Epoch 00124: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0124
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0124/assets
# Epoch 125/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.3004 - accuracy: 0.8805 - val_loss: 0.3214 - val_accuracy: 0.8735
#
# Epoch 00125: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0125
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0125/assets
# Epoch 126/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2900 - accuracy: 0.8828 - val_loss: 0.3106 - val_accuracy: 0.8756
#
# Epoch 00126: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0126
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0126/assets
# Epoch 127/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2733 - accuracy: 0.8940 - val_loss: 0.3267 - val_accuracy: 0.8754
#
# Epoch 00127: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0127
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0127/assets
# Epoch 128/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2870 - accuracy: 0.8861 - val_loss: 0.3186 - val_accuracy: 0.8725
#
# Epoch 00128: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0128
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0128/assets
# Epoch 129/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2908 - accuracy: 0.8835 - val_loss: 0.3207 - val_accuracy: 0.8678
#
# Epoch 00129: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0129
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0129/assets
# Epoch 130/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2868 - accuracy: 0.8814 - val_loss: 0.3149 - val_accuracy: 0.8748
#
# Epoch 00130: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0130
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0130/assets
# Epoch 131/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2944 - accuracy: 0.8784 - val_loss: 0.3111 - val_accuracy: 0.8755
#
# Epoch 00131: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0131
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0131/assets
# Epoch 132/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2784 - accuracy: 0.8868 - val_loss: 0.3190 - val_accuracy: 0.8737
#
# Epoch 00132: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0132
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0132/assets
# Epoch 133/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2913 - accuracy: 0.8809 - val_loss: 0.3140 - val_accuracy: 0.8736
#
# Epoch 00133: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0133
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0133/assets
# Epoch 134/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2771 - accuracy: 0.8890 - val_loss: 0.3208 - val_accuracy: 0.8723
#
# Epoch 00134: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0134
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0134/assets
# Epoch 135/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2892 - accuracy: 0.8810 - val_loss: 0.3113 - val_accuracy: 0.8777
#
# Epoch 00135: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0135
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0135/assets
# Epoch 136/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2754 - accuracy: 0.8930 - val_loss: 0.3167 - val_accuracy: 0.8724
#
# Epoch 00136: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0136
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0136/assets
# Epoch 137/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2671 - accuracy: 0.8971 - val_loss: 0.3165 - val_accuracy: 0.8736
#
# Epoch 00137: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0137
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0137/assets
# Epoch 138/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2814 - accuracy: 0.8840 - val_loss: 0.3149 - val_accuracy: 0.8715
#
# Epoch 00138: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0138
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0138/assets
# Epoch 139/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2855 - accuracy: 0.8930 - val_loss: 0.3184 - val_accuracy: 0.8762
#
# Epoch 00139: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0139
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0139/assets
# Epoch 140/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2807 - accuracy: 0.8874 - val_loss: 0.3267 - val_accuracy: 0.8698
#
# Epoch 00140: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0140
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0140/assets
# Epoch 141/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2790 - accuracy: 0.8915 - val_loss: 0.3101 - val_accuracy: 0.8779
#
# Epoch 00141: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0141
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0141/assets
# Epoch 142/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2823 - accuracy: 0.8860 - val_loss: 0.3213 - val_accuracy: 0.8774
#
# Epoch 00142: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0142
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0142/assets
# Epoch 143/250
# ...
#
# Epoch 00203: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0203
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0203/assets
# Epoch 204/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2585 - accuracy: 0.8995 - val_loss: 0.3093 - val_accuracy: 0.8849
#
# Epoch 00204: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0204
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0204/assets
# Epoch 205/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2604 - accuracy: 0.8993 - val_loss: 0.3175 - val_accuracy: 0.8801
#
# Epoch 00205: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0205
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0205/assets
# Epoch 206/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2719 - accuracy: 0.8874 - val_loss: 0.3092 - val_accuracy: 0.8800
#
# Epoch 00206: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0206
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0206/assets
# Epoch 207/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2497 - accuracy: 0.8994 - val_loss: 0.3137 - val_accuracy: 0.8792
#
# Epoch 00207: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0207
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0207/assets
# Epoch 208/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2596 - accuracy: 0.8983 - val_loss: 0.3080 - val_accuracy: 0.8844
#
# Epoch 00208: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0208
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0208/assets
# Epoch 209/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2414 - accuracy: 0.9039 - val_loss: 0.3073 - val_accuracy: 0.8836
#
# Epoch 00209: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0209
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0209/assets
# Epoch 210/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2636 - accuracy: 0.8976 - val_loss: 0.3057 - val_accuracy: 0.8850
#
# Epoch 00210: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0210
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0210/assets
# Epoch 211/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2629 - accuracy: 0.8964 - val_loss: 0.3138 - val_accuracy: 0.8841
#
# Epoch 00211: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0211
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0211/assets
# Epoch 212/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2436 - accuracy: 0.9054 - val_loss: 0.3104 - val_accuracy: 0.8816
#
# Epoch 00212: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0212
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0212/assets
# Epoch 213/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2406 - accuracy: 0.9039 - val_loss: 0.3077 - val_accuracy: 0.8818
#
# Epoch 00213: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0213
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0213/assets
# Epoch 214/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2495 - accuracy: 0.8987 - val_loss: 0.3153 - val_accuracy: 0.8771
#
# Epoch 00214: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0214
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0214/assets
# Epoch 215/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2424 - accuracy: 0.9028 - val_loss: 0.3138 - val_accuracy: 0.8792
#
# Epoch 00215: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0215
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0215/assets
# Epoch 216/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2517 - accuracy: 0.9034 - val_loss: 0.3120 - val_accuracy: 0.8823
#
# Epoch 00216: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0216
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0216/assets
# Epoch 217/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2557 - accuracy: 0.9012 - val_loss: 0.3135 - val_accuracy: 0.8758
#
# Epoch 00217: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0217
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0217/assets
# Epoch 218/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2504 - accuracy: 0.9029 - val_loss: 0.3109 - val_accuracy: 0.8790
#
# Epoch 00218: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0218
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0218/assets
# Epoch 219/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2401 - accuracy: 0.9066 - val_loss: 0.3161 - val_accuracy: 0.8813
#
# Epoch 00219: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0219
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0219/assets
# Epoch 220/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2705 - accuracy: 0.8943 - val_loss: 0.3187 - val_accuracy: 0.8817
#
# Epoch 00220: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0220
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0220/assets
# Epoch 221/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2609 - accuracy: 0.8966 - val_loss: 0.3158 - val_accuracy: 0.8815
#
# Epoch 00221: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0221
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0221/assets
# Epoch 222/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2391 - accuracy: 0.9042 - val_loss: 0.3063 - val_accuracy: 0.8834
#
# Epoch 00222: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0222
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0222/assets
# Epoch 223/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2514 - accuracy: 0.9002 - val_loss: 0.3061 - val_accuracy: 0.8806
#
# Epoch 00223: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0223
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0223/assets
# Epoch 224/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2615 - accuracy: 0.8959 - val_loss: 0.3188 - val_accuracy: 0.8823
#
# Epoch 00224: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0224
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0224/assets
# Epoch 225/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2432 - accuracy: 0.9038 - val_loss: 0.3202 - val_accuracy: 0.8823
#
# Epoch 00225: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0225
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0225/assets
# Epoch 226/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2540 - accuracy: 0.9011 - val_loss: 0.3056 - val_accuracy: 0.8840
#
# Epoch 00226: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0226
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0226/assets
# Epoch 227/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2412 - accuracy: 0.9034 - val_loss: 0.3127 - val_accuracy: 0.8779
#
# Epoch 00227: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0227
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0227/assets
# Epoch 228/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2700 - accuracy: 0.8929 - val_loss: 0.3142 - val_accuracy: 0.8851
#
# Epoch 00228: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0228
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0228/assets
# Epoch 229/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2449 - accuracy: 0.9002 - val_loss: 0.3071 - val_accuracy: 0.8793
#
# Epoch 00229: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0229
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0229/assets
# Epoch 230/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2448 - accuracy: 0.9016 - val_loss: 0.3075 - val_accuracy: 0.8824
#
# Epoch 00230: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0230
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0230/assets
# Epoch 231/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2513 - accuracy: 0.8998 - val_loss: 0.3111 - val_accuracy: 0.8823
#
# Epoch 00231: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0231
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0231/assets
# Epoch 232/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2389 - accuracy: 0.9072 - val_loss: 0.3093 - val_accuracy: 0.8847
#
# Epoch 00232: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0232
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0232/assets
# Epoch 233/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2519 - accuracy: 0.9005 - val_loss: 0.3124 - val_accuracy: 0.8796
#
# Epoch 00233: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0233
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0233/assets
# Epoch 234/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2583 - accuracy: 0.8957 - val_loss: 0.3129 - val_accuracy: 0.8796
#
# Epoch 00234: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0234
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0234/assets
# Epoch 235/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2497 - accuracy: 0.8992 - val_loss: 0.3104 - val_accuracy: 0.8823
#
# Epoch 00235: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0235
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0235/assets
# Epoch 236/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2453 - accuracy: 0.9005 - val_loss: 0.3088 - val_accuracy: 0.8837
#
# Epoch 00236: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0236
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0236/assets
# Epoch 237/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2439 - accuracy: 0.9054 - val_loss: 0.3030 - val_accuracy: 0.8866
#
# Epoch 00237: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0237
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0237/assets
# Epoch 238/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2454 - accuracy: 0.9011 - val_loss: 0.3025 - val_accuracy: 0.8837
#
# Epoch 00238: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0238
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0238/assets
# Epoch 239/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2416 - accuracy: 0.9044 - val_loss: 0.3129 - val_accuracy: 0.8831
#
# Epoch 00239: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0239
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0239/assets
# Epoch 240/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2458 - accuracy: 0.9040 - val_loss: 0.3115 - val_accuracy: 0.8795
#
# Epoch 00240: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0240
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0240/assets
# Epoch 241/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2417 - accuracy: 0.9015 - val_loss: 0.3084 - val_accuracy: 0.8832
#
# Epoch 00241: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0241
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0241/assets
# Epoch 242/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2335 - accuracy: 0.9095 - val_loss: 0.3115 - val_accuracy: 0.8844
#
# Epoch 00242: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0242
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0242/assets
# Epoch 243/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2441 - accuracy: 0.9014 - val_loss: 0.3099 - val_accuracy: 0.8858
#
# Epoch 00243: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0243
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0243/assets
# Epoch 244/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2455 - accuracy: 0.9025 - val_loss: 0.3135 - val_accuracy: 0.8854
#
# Epoch 00244: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0244
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0244/assets
# Epoch 245/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2540 - accuracy: 0.8980 - val_loss: 0.3109 - val_accuracy: 0.8854
#
# Epoch 00245: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0245
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0245/assets
# Epoch 246/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2417 - accuracy: 0.9003 - val_loss: 0.3147 - val_accuracy: 0.8841
#
# Epoch 00246: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0246
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0246/assets
# Epoch 247/250
# 70/70 [==============================] - 1s 13ms/step - loss: 0.2515 - accuracy: 0.9037 - val_loss: 0.3359 - val_accuracy: 0.8685
#
# Epoch 00247: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0247
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0247/assets
# Epoch 248/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2589 - accuracy: 0.8906 - val_loss: 0.3167 - val_accuracy: 0.8832
#
# Epoch 00248: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0248
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0248/assets
# Epoch 249/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2386 - accuracy: 0.9035 - val_loss: 0.3091 - val_accuracy: 0.8830
#
# Epoch 00249: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0249
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0249/assets
# Epoch 250/250
# 70/70 [==============================] - 1s 12ms/step - loss: 0.2468 - accuracy: 0.9052 - val_loss: 0.3183 - val_accuracy: 0.8846
#
# Epoch 00250: saving model to /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0250
# INFO:tensorflow:Assets written to: /data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/E-0250/assets

# %%
# out = f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/U-Net/'

with open(s, "rb") as file_pi:
    history = pickle.load(file_pi)
accs = history['accuracy']
val_accs = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']

plt.figure()
plt.plot(accs, color='red', label='acc')
plt.plot(val_accs, color='blue', label='val acc')

plt.ylim((.5,1.))

plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.title('Acc. v.s. Epoch')

plt.figure()
plt.plot(loss, color='red', label='loss')
plt.plot(val_loss, color='blue', label='val_loss')

plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.title('Loss v.s. Epoch')
# plt.savefig('/data/keeling/a/jdnied2/c/MS_THESIS/Models/Plots/MLPS_batch_test.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Loss v.s. Epoch')

# %%
out = f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/UNET/'

model = tf.keras.models.load_model(f'{out}/E-0250/', 
                                 compile=False)
start = time.time()
model_predictions = model.predict(testing_rad)
end = time.time()
print(end-start)
model_predictions.shape
# Out:
# 28.953370332717896
# (100, 64, 64, 2)

# %%
#binary
@jit(nopython=True)                         
def CM_G(predictions, masks, image_n):
    ML_layer_0=predictions[image_n,:,:,0]
    ML_layer_1=predictions[image_n,:,:,1]

    x_axis_lim = IMG_DIM
    y_axis_lim = IMG_DIM
    
    for x in range(x_axis_lim):
        for y in range(y_axis_lim):
            if ML_layer_0[x,y] > ML_layer_1[x,y]:
                masks[image_n,x,y] = 0
            else:
                masks[image_n,x,y] = 1

    
    return masks

start = timer()
model_masks = np.zeros((np.shape(model_predictions)[0],IMG_DIM,IMG_DIM))
for image_n in tqdm(range(len(model_predictions))):
    masks=CM_G(model_predictions,model_masks,image_n)
print("with GPU:", timer()-start)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 21
#      18     return masks
#      20 start = timer()
# ---> 21 model_masks = np.zeros((np.shape(model_predictions)[0],IMG_DIM,IMG_DIM))
#      22 for image_n in tqdm(range(len(model_predictions))):
#      23     masks=CM_G(model_predictions,model_masks,image_n)
#
# NameError: name 'model_predictions' is not defined

# %%
np.sum(np.unique(testing_cmask[:], return_counts=True)[1][:2])
# Out:
# 395590

# %%
# testing_cmask[0]
np.sum(masks[:]==testing_cmask[:])/(100*64**2
                                   )
# Out:
# 0.81840087890625

# %%
# @jit(nopython=True)                         
def confusion_matrix_generate(ML_mask, TRUTH_mask, CM_data):
    for x in range(IMG_DIM):
        for y in range(IMG_DIM):
            ML_pixel = int(ML_mask[x,y])
            TRUTH_pixel = TRUTH_mask[x,y]
            if not np.isnan(TRUTH_pixel):
                TRUTH_pixel = int(TRUTH_pixel)
                CM_data[ML_pixel,TRUTH_pixel]+=1

    return CM_data

n_classes=2
CM_data = np.zeros((2,2))
total_pixels = 0
for ML_mask, TRUTH_mask in zip(masks, testing_cmask):
    CM_data = confusion_matrix_generate(ML_mask, TRUTH_mask, CM_data)
    total_pixels+=IMG_DIM**2

# %%
(CM_data/395590)[0,0]+(CM_data/395590)[1,1]
# Out:
# 0.847384918728987

# %%
(CM_data/total_pixels)*100
# Out:
# array([[52.0625    ,  2.57128906],
#        [12.11791992, 29.82788086]])

# %% [markdown]
# # MISR

# %%
filenames = use_files[-100:]

# %%
mod_rad, mod_cm = get_modis_data([1,2,20,26,27,29,31,32,35], np.array(filenames))
misr_cm = np.zeros(np.shape(mod_cm))
for i, f in enumerate(np.array(filenames)):
    date = f.split('_')[-3]
    im_n = f.split('+')[-1]
    misr_cm[i] = np.load(glob.glob(f'/data/gdi/c/gzhao1/joseph/rccm/{im_n}*{date}*.npy')[0])
misr_cm = make_binary(misr_cm - 1)
mod_cm = make_binary(mod_cm)

stats = []
for i in range(100):
    total_p = 0
    success = 0
    for x in range(64):
        for y in range(64):
            misr_p = misr_cm[i,x,y]
            if misr_p != -1:
                total_p += 1.
                if misr_p == mod_cm[i,x,y]:
                    success += 1.
    stats.append(success/total_p)
# Out:
# ['Band_1.0', 'Band_2.0', 'Band_20.0', 'Band_26.0', 'Band_27.0', 'Band_29.0', 'Band_31.0', 'Band_32.0', 'Band_35.0']
#   0%|          | 0/100 [00:00<?, ?it/s]
# (100, 9, 64, 64)
# (100, 64, 64, 9)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 6
#       4     date = f.split('_')[-3]
#       5     im_n = f.split('+')[-1]
# ----> 6     misr_cm[i] = np.load(glob.glob(f'/data/gdi/c/gzhao1/joseph/rccm/{im_n}*{date}*.npy')[0])
#       7 misr_cm = make_binary(misr_cm - 1)
#       8 mod_cm = make_binary(mod_cm)
#
# IndexError: list index out of range

# %%
# showing 10 and 42
i=410 # 30 31 32 42
# 39 perfect
fig,ax = plt.subplots(2,3,sharex=True,sharey=True)
ax[0,0].imshow(mod_rad[i,:,:,1], vmin=0, vmax=8, cmap='gray')
ax[0,1].imshow(mod_rad[i,:,:,-3], vmin=8.0, vmax=9.5, cmap='gray_r')
ax[0,2].imshow(misr_cm[i]-mod_cm[i], cmap = 'bwr_r')
ax[1,0].imshow(misr_cm[i], cmap='gray_r')
ax[1,1].imshow(mod_cm[i], cmap='gray_r')
ax[1,2].imshow(masks[i-400], cmap='gray_r')

ax[0,0].set_title(r'Band 2 - .86 $\mu$m')
ax[0,1].set_title(r'Band 31 - 11$\mu$m')
ax[0,2].set_title('MOD35-RCCM')
ax[1,0].set_title('RCCM')
ax[1,1].set_title('MOD35')
ax[1,2].set_title('ML')


for a in range(2):
    for b in range(3):
        ax[a,b].set_xticks([])
        ax[a,b].set_yticks([])

# %%
mod_dnn = f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/Inner-Compare/DNN/'
mod_cnn = f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/Inner-Compare/CNN/'
misr_dnn = f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/DNN/'
misr_cnn = f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/CNN/'
model_mod_dnn = tf.keras.models.load_model(f'{mod_dnn}/E-0250/', 
                                 compile=False)
model_mod_cnn = tf.keras.models.load_model(f'{mod_cnn}/E-0250/', 
                                 compile=False)
model_misr_dnn = tf.keras.models.load_model(f'{misr_dnn}/E-0250/', 
                                 compile=False)
model_misr_cnn = tf.keras.models.load_model(f'{misr_cnn}/E-0250/', 
                                 compile=False)
modc_out = model_mod_cnn.predict(testing_rad)
misc_out = model_misr_cnn.predict(testing_rad)
modd_out = model_mod_dnn.predict(test_rad_flat)
misd_out = model_misr_dnn.predict(test_rad_flat)

modc_masks = np.zeros((np.shape(modc_out)[0],IMG_DIM,IMG_DIM))
misc_masks = np.zeros((np.shape(modc_out)[0],IMG_DIM,IMG_DIM))
for image_n in tqdm(range(len(modc_out))):
    modc_masks=CM_G(modc_out,modc_masks,image_n)
for image_n in tqdm(range(len(misc_out))):
    misc_masks=CM_G(misc_out,misc_masks,image_n)
CM,modd_masks,num_pixels = CM_G_flat(modd_out, test_labels_1hot, CM)
modd_masks = np.reshape(modd_masks,(100,64,64))
CM,misd_masks,num_pixels = CM_G_flat(misd_out, test_labels_1hot, CM)
misd_masks = np.reshape(misd_masks,(100,64,64))
# Out:
# 2024-06-19 11:33:35.432704: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-06-19 11:33:35.434324: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2600240000 Hz
# 2024-06-19 11:33:35.587169: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-06-19 11:33:37.089023: E tensorflow/stream_executor/cuda/cuda_dnn.cc:336] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2024-06-19 11:33:37.128404: E tensorflow/stream_executor/cuda/cuda_dnn.cc:336] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2024-06-19 11:33:37.128498: W tensorflow/core/framework/op_kernel.cc:1763] OP_REQUIRES failed at conv_ops_fused_impl.h:697 : Unknown: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# Cell In[27], line 13
#       9 model_misr_dnn = tf.keras.models.load_model(f'{misr_dnn}/E-0250/',
#      10                                  compile=False)
#      11 model_misr_cnn = tf.keras.models.load_model(f'{misr_cnn}/E-0250/',
#      12                                  compile=False)
# ---> 13 modc_out = model_mod_cnn.predict(testing_rad)
#      14 misc_out = model_misr_cnn.predict(testing_rad)
#      15 modd_out = model_mod_dnn.predict(test_rad_flat)
#
# File ~/miniconda3/envs/TF_RF_GPU/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1629, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627 for step in data_handler.steps():
#    1628   callbacks.on_predict_batch_begin(step)
# -> 1629   tmp_batch_outputs = self.predict_function(iterator)
#    1630   if data_handler.should_sync:
#    1631     context.async_wait()
#
# File ~/miniconda3/envs/TF_RF_GPU/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:828, in Function.__call__(self, *args, **kwds)
#     826 tracing_count = self.experimental_get_tracing_count()
#     827 with trace.Trace(self._name) as tm:
# --> 828   result = self._call(*args, **kwds)
#     829   compiler = "xla" if self._experimental_compile else "nonXla"
#     830   new_tracing_count = self.experimental_get_tracing_count()
#
# File ~/miniconda3/envs/TF_RF_GPU/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:894, in Function._call(self, *args, **kwds)
#     890   _, _, _, filtered_flat_args = \
#     891       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     892           *args, **kwds)
#     893   # If we did not create any variables the trace we have is good enough.
# --> 894   return self._concrete_stateful_fn._call_flat(
#     895       filtered_flat_args, self._concrete_stateful_fn.captured_inputs)  # pylint: disable=protected-access
#     897 def fn_with_cond(inner_args, inner_kwds, inner_filtered_flat_args):
#     898   """Conditionally runs initialization if it's needed."""
#
# File ~/miniconda3/envs/TF_RF_GPU/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1918, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1914 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1915 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1916     and executing_eagerly):
#    1917   # No tape is watching; skip to running the function.
# -> 1918   return self._build_call_outputs(self._inference_function.call(
#    1919       ctx, args, cancellation_manager=cancellation_manager))
#    1920 forward_backward = self._select_forward_and_backward_functions(
#    1921     args,
#    1922     possible_gradient_type,
#    1923     executing_eagerly)
#    1924 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/TF_RF_GPU/lib/python3.9/site-packages/tensorflow/python/eager/function.py:555, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     553 with _InterpolateFunctionError(self):
#     554   if cancellation_manager is None:
# --> 555     outputs = execute.execute(
#     556         str(self.signature.name),
#     557         num_outputs=self._num_outputs,
#     558         inputs=args,
#     559         attrs=attrs,
#     560         ctx=ctx)
#     561   else:
#     562     outputs = execute.execute_with_cancellation(
#     563         str(self.signature.name),
#     564         num_outputs=self._num_outputs,
#    (...)
#     567         ctx=ctx,
#     568         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/TF_RF_GPU/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# UnknownError:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node model/conv2d/Relu (defined at tmp/ipykernel_72756/380481984.py:13) ]] [Op:__inference_predict_function_4910]
#
# Function call stack:
# predict_function

# %%
fig, ax = plt.subplots(1,1)
ax.set_xticks([])
ax.set_yticks([])
plt.imshow(mod_rad[i+400,:,:,3], vmin=.05,cmap='gray')
cbar = plt.colorbar(extend='both')
cbar.ax.set_ylabel(r'$Wm^{-2}sr^{-1}$', labelpad=20, rotation=270)
plt.title(r'Band 20 - 3.75 $\mu$m')
# plt.savefig(f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/Plots/artif.png')

# %%
# showing 10, 42, & 30
import matplotlib.patches as mpatches
font = {
        'size'   : 28
}
matplotlib.rc('font', **font)

def add_colorbar(im, ax, vis=True):
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)
    if vis:
        plt.colorbar(im, cax=cax, extend='max', label=r'$Wm^{-2}sr^{-1}$')
    else:
        plt.colorbar(im, cax=cax, extend='both', label=r'$Wm^{-2}sr^{-1}$')


i=42 # 30 31 32 42
# 39 perfect
fig,ax = plt.subplots(2,4, figsize=(30,12),
                      sharex=True,sharey=True)
im1 = ax[0,0].imshow(mod_rad[i+400,:,:,1], vmin=0, vmax=40, cmap='gray')
im2 = ax[1,0].imshow(mod_rad[i+400,:,:,-3], vmin=7.5, vmax=9.5, cmap='gray_r')
ax[0,1].imshow(mod_cm[i+400], cmap = 'gray_r')
ax[1,1].imshow(misr_cm[i+400], cmap='gray_r')
ax[0,2].imshow(modd_masks[i], cmap='gray_r')
ax[1,2].imshow(misd_masks[i], cmap='gray_r')
ax[0,3].imshow(modc_masks[i], cmap='gray_r')
ax[1,3].imshow(misc_masks[i], cmap='gray_r')

add_colorbar(im1, ax[0, 0])
add_colorbar(im2, ax[1, 0], False)



ax[0,0].set_title(r'Band 2 - .86 $\mu$m')
ax[1,0].set_title(r'Band 31 - 11$\mu$m')
ax[1,1].set_title('MISR RCCM')
ax[0,1].set_title('MODIS MOD35')
ax[0,2].set_title('DNN MODIS')
ax[1,2].set_title('DNN MISR')
ax[0,3].set_title('CNN MODIS')
ax[1,3].set_title('CNN MISR')


for a in range(2):
    for b in range(4):
        ax[a,b].set_xticks([])
        ax[a,b].set_yticks([])
        
white_patch = mpatches.Patch(facecolor='white', edgecolor='black', label='Cloudy', linewidth=2)
black_patch = mpatches.Patch(facecolor='black', edgecolor='black', label='Clear-Sky', linewidth=2)
ax[1,3].legend(handles=[white_patch, black_patch], bbox_to_anchor=(2, 0.5))

plt.tight_layout()
# plt.savefig(f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/Plots/MODIS-MISR-ML-{i}.png')
# Out:
# <img src="data:image/png;base64,..." width="3000">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 21
#      18 # 39 perfect
#      19 fig,ax = plt.subplots(2,4, figsize=(30,12),
#      20                       sharex=True,sharey=True)
# ---> 21 im1 = ax[0,0].imshow(mod_rad[i+400,:,:,1], vmin=0, vmax=40, cmap='gray')
#      22 im2 = ax[1,0].imshow(mod_rad[i+400,:,:,-3], vmin=7.5, vmax=9.5, cmap='gray_r')
#      23 ax[0,1].imshow(mod_cm[i+400], cmap = 'gray_r')
#
# IndexError: index 442 is out of bounds for axis 0 with size 100

# %% [markdown]
# # Layer Investigate

# %%
plt.figure()
i=42
plt.imshow(testing_rad[i,:,:,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
model_misr_cnn.layers[1:-1]
# Out:
# [<tensorflow.python.keras.layers.convolutional.Conv2D at 0x2ac7dd58d2e0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x2ac7dd58db50>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x2ac7dd56a460>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x2ac7dd4994c0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x2ac7dd56ae80>]

# %%
L=4
layer_outputs = [layer.output for layer in model_misr_cnn.layers[L:-1]] 
iterate = tf.keras.models.Model([model_misr_cnn.inputs], layer_outputs)
imi=42
x = testing_rad[imi:imi+1,:,:,:]
outputs = iterate(x)

# %%
outputs[0].shape
# Out:
# TensorShape([1, 64, 64, 512])

# %%
plt.figure()
plt.imshow(outputs[0][0,:,:,0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots(4,4, figsize=(8,8))

for i in range(4):
    for j in range(4):
        ax[i,j].set_xticks([])
        ax[i,j].set_yticks([])
        ax[i,j].imshow(outputs[0][0,:,:,(i+1)*j])
ax[0,0].text(-30, -40, 'A', fontsize=40, fontweight="bold", va="top", ha="left")
# fig.suptitle('MISR CNN - Layer 4 Feature Maps')
plt.tight_layout()
plt.savefig(f'/data/keeling/a/jdnied2/c/MS_THESIS/Support_Figs/CNN_Layer_{L}_fmap_image_{imi}.png')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure()
plt.plot(stats)
print((np.sum(mod_cm==misr_cm)-np.sum(misr_cm==-1))/((64*64*100)-np.sum(misr_cm==-1)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 3.95264892578125

# %%
# 1.) Get ACc/epoch for testing data
# 2.) generate .gif for image 10 and 42 for every epoch

# %%
out = f'/data/keeling/a/jdnied2/c/MS_THESIS/Models/MISR/UNET/'

model = tf.keras.models.load_model(f'{out}/E-0250/', 
                                 compile=False)
start = time.time()
model_predictions = model.predict(testing_rad)

# %% [markdown]
# # Old

# %%
CM_per = np.round((CM_data/total_pixels)*100,2)
print(CM_per)
# axis_labels = ['cloudy', 'probably\ncloudy', 'probably\nclear', 'confident\nclear',]
axis_labels = ['cloudy', 'clear',]

plt.figure()
ax = sn.heatmap(CM_per, annot=True, 
           xticklabels=axis_labels, 
           yticklabels=axis_labels, fmt='.1f')
ax.set(ylabel='Manual Thresholding', xlabel='MODIS Cloud Mask Truth')
# Out:
# [[51.17  0.  ]
#  [48.83  0.  ]]
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 7
#       4 axis_labels = ['cloudy', 'clear',]
#       6 plt.figure()
# ----> 7 ax = sn.heatmap(CM_per, annot=True,
#       8            xticklabels=axis_labels,
#       9            yticklabels=axis_labels, fmt='.1f')
#      10 ax.set(ylabel='Manual Thresholding', xlabel='MODIS Cloud Mask Truth')
#
# NameError: name 'sn' is not defined

# %%
CM_per

# %% [markdown]
# # LOAD TRAINED MODEL

# %%
# out = '/data/keeling/a/jdnied2/c/ML_OUT_TEMP/MODIS/spectral_models/norm/cnn_basic_4labels_v2'
# out = '/data/keeling/a/jdnied2/c/ML_OUT_TEMP/MODIS/spectral_models/norm/cnn_batchnorm_2labels_v2/'

out = '/data/keeling/a/jdnied2/c/ML_OUT_TEMP/MODIS/spectral_models/norm_4band/cnn_basic_v1/'


s = f'{out}/history/hist'
with open(s, "rb") as file_pi:
    history = pickle.load(file_pi)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2)
for ax in axes.flat:
    im = ax.imshow(np.random.random((10,10)), vmin=0, vmax=1)

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)
fig.set_figheight(15)
fig.set_figwidth(15)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
acc = history['accuracy']
val_acc = history['val_accuracy']
plt.figure()
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Value Accuracy')
plt.title(f'Model: {out.split("/")[-2]}')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.xlim()
# plt.ylim((.65,.95))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
epoch_1 = 'E-0001'
epoch_2 = 'E-0100'

model_1 = tf.keras.models.load_model(f'{out}/{epoch_1}/')
model_2 = tf.keras.models.load_model(f'{out}/{epoch_2}/')

# %% [markdown]
# # Spectral Kernel Inv

# %%
np.shape(model_2.layers[4].get_weights())
# Out:
# (0,)

# %%
lay_num = 1

labels = ((np.array(bands_to_use)[[0,2,3,6]]).tolist())
labels.append('bias')
lay_1_1 = model_1.layers[lay_num]
w_1, b_1 = lay_1_1.get_weights()
_, _, ch_size, k_num = w_1.shape
print( w_1.shape)
w_flat_1 = np.reshape(w_1,(ch_size, k_num))
combined_1 = np.zeros((ch_size+1, k_num))
combined_1[0:ch_size,:] = w_flat_1
combined_1[ch_size:,:] = b_1

lay_2_1 = model_2.layers[lay_num]
w_2, b_2 = lay_2_1.get_weights()
w_flat_2 = np.reshape(w_2,(ch_size, k_num))
combined_2 = np.zeros((ch_size+1, k_num))
combined_2[0:ch_size,:] = w_flat_2
combined_2[ch_size:,:] = b_2


fig, ax = plt.subplots(3,1)

ax1 = ax[0]
im1 = ax1.imshow(combined_1, cmap='RdBu', interpolation='None')
divider = make_axes_locatable(ax1)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im1, cax=cax, orientation='vertical')
ax1.yaxis.set_ticks(ticks=range(NUM_OF_CHANNELS+1), labels=labels)


ax2 = ax[1]
im2 = ax2.imshow(combined_2, cmap='RdBu', interpolation='None')
divider = make_axes_locatable(ax2)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im2, cax=cax, orientation='vertical');
ax2.yaxis.set_ticks(ticks=range(NUM_OF_CHANNELS+1), labels=labels)

ax3 = ax[2]
im3 = ax3.imshow(combined_1-combined_2, cmap='RdBu', interpolation='None')
divider = make_axes_locatable(ax3)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im3, cax=cax, orientation='vertical');
ax3.yaxis.set_ticks(ticks=range(NUM_OF_CHANNELS+1), labels=labels)



# fig, ax = plt.subplots(2)
# ax[0].imshow(w_flat_1, cmap='RdBu')
# plt.colorbar()
# Out:
# (1, 1, 4, 32)
# <img src="data:image/png;base64,..." width="639.999990463257">
# [<matplotlib.axis.YTick at 0x2b0777e7faf0>,
#  <matplotlib.axis.YTick at 0x2b0777e7f9d0>,
#  <matplotlib.axis.YTick at 0x2b0777e739d0>,
#  <matplotlib.axis.YTick at 0x2b0777f82fd0>,
#  <matplotlib.axis.YTick at 0x2b0777f93940>]

# %%
lay_num = 2

# labels = ((np.array(bands_to_use)[[0,2,3,6]]).tolist())
# labels.append('bias')
lay_1_1 = model_1.layers[lay_num]
w_1, b_1 = lay_1_1.get_weights()
_, _, ch_size, k_num = w_1.shape
print( w_1.shape)
w_flat_1 = np.reshape(w_1,(ch_size, k_num))
combined_1 = np.zeros((ch_size+1, k_num))
combined_1[0:ch_size,:] = w_flat_1
combined_1[ch_size:,:] = b_1

lay_2_1 = model_2.layers[lay_num]
w_2, b_2 = lay_2_1.get_weights()
w_flat_2 = np.reshape(w_2,(ch_size, k_num))
combined_2 = np.zeros((ch_size+1, k_num))
combined_2[0:ch_size,:] = w_flat_2
combined_2[ch_size:,:] = b_2


fig, ax = plt.subplots(1,3)

ax1 = ax[0]
im1 = ax1.imshow(combined_1, cmap='RdBu', interpolation='None')
divider = make_axes_locatable(ax1)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im1, cax=cax, orientation='vertical')


ax2 = ax[1]
im2 = ax2.imshow(combined_2, cmap='RdBu', interpolation='None')
divider = make_axes_locatable(ax2)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im2, cax=cax, orientation='vertical');

ax3 = ax[2]
im3 = ax3.imshow(combined_1-combined_2, cmap='RdBu', interpolation='None')
divider = make_axes_locatable(ax3)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im3, cax=cax, orientation='vertical');

# fig, ax = plt.subplots(2)
# ax[0].imshow(w_flat_1, cmap='RdBu')
# plt.colorbar()
# Out:
# (1, 1, 32, 32)
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
np.argmax(np.absolute(b_2))
# Out:
# 6

# %%
lay_test_1 = model_2.layers[1]
lay_test_2 = model_2.layers[2]
lay_test_3 = model_2.layers[3]

w1, b1 = lay_test_1.get_weights()
w2, b2 = lay_test_2.get_weights()
w3, b3 = lay_test_3.get_weights()

print(w1.shape, w2.shape, w3.shape)
# Out:
# (1, 1, 4, 32) (1, 1, 32, 32) (1, 1, 32, 2)

# %%
x = np.matmul(b1+w1[0,0],b2+w2[0,0])
y = np.matmul(x,b3+w3[0,0])
plt.figure()
# fig, ax = plt.subplots(1,2)
# ax[0].imshow(x, cmap='RdBu')
plt.imshow(y, cmap='RdBu')
plt.yticks(ticks=range(9), labels=bands_to_use)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
predictions = model_2.predict(human_rad_norm[:,:,:,[0,2,3,6]])

# %%
model_2.layers[-1](z)[:,:,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 model_2.layers[-1](z)[:,:,1]
#
# NameError: name 'z' is not defined

# %%
# np.matm
human_rad_norm[im_n,:,:,:].shape
z = np.matmul(human_rad_norm[im_n,:,:,:],y)
print(z.shape)
plt.figure()
plt.imshow(model_2.layers[-1](z)[:,:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[182], line 3
#       1 # np.matm
#       2 human_rad_norm[im_n,:,:,:].shape
# ----> 3 z = np.matmul(human_rad_norm[im_n,:,:,:],y)
#       4 print(z.shape)
#       5 plt.figure()
#
# NameError: name 'y' is not defined

# %%
im_n=0
plt.figure()
plt.imshow(predictions[im_n,:,:,1])
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.figure()
plt.imshow(human_masks[100])
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
b_n=2
plt.figure()
print(bands_to_use[b_n])
plt.imshow(human_rad[im_n,:,:,b_n])
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# 20

# %%
lay = cnn.layers[2]
print(lay)
w, b = lay.get_weights()
print(np.shape(w))
print(np.shape(b))
w_flat = np.reshape(w,(32,32))
final = np.zeros((33,32))
final[0:32,:] = w_flat
final[32:,:] = b
plt.figure()
plt.imshow(final)
plt.colorbar()
# plt.yticks(ticks=range(9), labels=bands_to_use)
# Out:
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b04e6674ca0>
# (1, 1, 32, 32)
# (32,)
# <img src="data:image/png;base64,..." width="639.999990463257">

# %% [markdown]
# # Visualize

# %%
model=model_2

# %%
layer_outputs = [layer.output for layer in model.layers] 
conv_flags = []
for lay in model.layers:
    layer_name = str(lay)
    print(layer_name)
    conv_flags.append('Conv2D' in layer_name)
conv_layers = []
for layer, flag in zip (layer_outputs, conv_flags):
    if flag:
        conv_layers.append(layer)
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x2b0774a59f70>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b07768cfa90>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b076f8fe850>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b0774d46640>
# <tensorflow.python.keras.layers.core.Activation object at 0x2b0774d468e0>

# %%
from IPython.display import display, HTML
import ipywidgets as ipy

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# temp get img 
im_n=0
x = random_rad[im_n:im_n+1,:,:,[0,2,3,6]]
print(np.shape(x))
iterate = tf.keras.models.Model([model.inputs], conv_layers)
outputs = iterate(x)
print(len(outputs))
rad_images_reshaped_test = random_rad_norm[:,:,:,[0,2,3,6]]
# Out:
# (1, 64, 64, 4)
# 3

# %%
def plot_classify_new(layer_nums, image_num, iterate): 
    # %matplotlib notebook
    conv_input_layer = 0
    
    def update_output_plot(conv_input_layer, outputs, children):
        # get output shape
        clear_output()
        fig = plt.figure(figsize=(10,5), dpi=200)
        selected_layer = outputs[conv_input_layer]
        _, dim_x,dim_y, num_of_ks = np.shape(selected_layer)

        rows = num_of_ks/8
        for i in range(num_of_ks):
            ax = fig.add_subplot(int(rows),8,i+1)
            ax.imshow(selected_layer[0,:,:,i])
            ax.set_xticks([])
            ax.set_yticks([])
        display(ipy.HBox(children))

            
    def generate_new(iterate, im_n):
        x = rad_images_reshaped_test[im_n:im_n+1,:,:,:]
        outputs = iterate(x)
        return outputs
    
    def on_change(change):
        if change['type'] == 'change' and change['name'] == 'value':
            print("changed to %s" % change['new'])
            selected_slice = change['new']
            print(selected_slice)
    
    children = []

    
    # LAYER SELECTOR
    layer_select = ipy.Dropdown(
            options=layer_nums,
            value=layer_nums[0],
            description='Layer Selector',
            disabled=False
    )

    layer_select.observe(on_change)
    
    
    # IMAGE SELECTOR
    image_select = ipy.Dropdown(
            options=image_num,
            value=image_num[0],
            description='Image Selector',
            disabled=False
    )
                 
   

    image_select.observe(on_change)


    
    

    #Create button functionality for updating sliders
    update_button = ipy.Button(description='Load New Image')
    def on_c2(b):
        outputs = generate_new(iterate, image_select.value)
        update_output_plot(layer_select.value, outputs, children)
        
    update_button.on_click(on_c2)

    
        
    children.append(ipy.VBox([update_button,layer_select,image_select]))
    display(ipy.HBox(children))


iterate = tf.keras.models.Model([model.inputs], conv_layers)
plot_classify_new(range(len(outputs)),range(1000), iterate)
# Out:
# <img src="data:image/png;base64,..." width="1999.999970197678">
# HBox(children=(VBox(children=(Button(description='Load New Image', style=ButtonStyle()), Dropdown(description=…

# %%
im_n = 20
plt.figure()
plt.imshow(rad_images_reshaped_test[im_n,:,:,0])
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.figure()
plt.imshow(random_masks[im_n])
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
